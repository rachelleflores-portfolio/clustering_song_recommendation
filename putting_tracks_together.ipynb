# %% [markdown]
# # Putting spotify tracks together

# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import config

# %% [markdown]
# ### SPOTIPY CONNECTION

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=config.client_id, client_secret=config.client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, requests_timeout=120)

# %%
# CHECK SEARCH RESULTS
h = sp.search(q='year:2021', type='track', limit=50)

# %%
t= h["tracks"]["items"]

# %%
t
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#      'href': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM',
#      'id': '4oUHIQIBe0LHzYfvXNW4QM',
#      'name': 'Morgan Wallen',
#      'type': 'artist',
#      'uri': 'spotify:artist:4oUHIQIBe0LHzYfvXNW4QM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6JlCkqkqobGirPsaleJpFr'},
#    'href': 'https://api.spotify.com/v1/albums/6JlCkqkqobGirPsaleJpFr',
#    'id': '6JlCkqkqobGirPsaleJpFr',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737d6813fd233f3bc4977cceca',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027d6813fd233f3bc4977cceca',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517d6813fd233f3bc4977cceca',
#      'width': 64}],
#    'name': 'Dangerous: The Double Album',
#    'release_date': '2021-01-08',
#    'release_date_precision': 'day',
#    'total_tracks': 30,
#    'type': 'album',
#    'uri': 'spotify:album:6JlCkqkqobGirPsaleJpFr'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#     'href': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM',
#     'id': '4oUHIQIBe0LHzYfvXNW4QM',
#     'name': 'Morgan Wallen',
#     'type': 'artist',
#     'uri': 'spotify:artist:4oUHIQIBe0LHzYfvXNW4QM'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 178520,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG12004194'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3cBsEDNhFI9E82vPj3kvi3'},
#   'href': 'https://api.spotify.com/v1/tracks/3cBsEDNhFI9E82vPj3kvi3',
#   'id': '3cBsEDNhFI9E82vPj3kvi3',
#   'is_local': False,
#   'name': 'Wasted On You',
#   'popularity': 88,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:3cBsEDNhFI9E82vPj3kvi3'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#      'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#      'id': '12GqGscKJx3aE4t07u7eVZ',
#      'name': 'Peso Pluma',
#      'type': 'artist',
#      'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6USJaTtVIy0YH5hhzOWVHe'},
#    'href': 'https://api.spotify.com/v1/albums/6USJaTtVIy0YH5hhzOWVHe',
#    'id': '6USJaTtVIy0YH5hhzOWVHe',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273427d9aa38866b43ed45f6b0c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02427d9aa38866b43ed45f6b0c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851427d9aa38866b43ed45f6b0c',
#      'width': 64}],
#    'name': 'Por las Noches',
#    'release_date': '2021-06-11',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:6USJaTtVIy0YH5hhzOWVHe'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#     'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#     'id': '12GqGscKJx3aE4t07u7eVZ',
#     'name': 'Peso Pluma',
#     'type': 'artist',
#     'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 239845,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR96X2198154'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2VzCjpKvPB1l1tqLndtAQa'},
#   'href': 'https://api.spotify.com/v1/tracks/2VzCjpKvPB1l1tqLndtAQa',
#   'id': '2VzCjpKvPB1l1tqLndtAQa',
#   'is_local': False,
#   'name': 'Por las Noches',
#   'popularity': 92,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ba2f667c373e2d12343ac00b162886caca060c93?cid=8e3b4a50b2ff4b929df3b7105c7850fb',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2VzCjpKvPB1l1tqLndtAQa'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jku7tDXc6XoB6MO2hFuqg'},
#      'href': 'https://api.spotify.com/v1/artists/2jku7tDXc6XoB6MO2hFuqg',
#      'id': '2jku7tDXc6XoB6MO2hFuqg',
#      'name': 'Tory Lanez',
#      'type': 'artist',
#      'uri': 'spotify:artist:2jku7tDXc6XoB6MO2hFuqg'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5Gm2XKBgnlzd6qTi7LE1z2'},
#    'href': 'https://api.spotify.com/v1/albums/5Gm2XKBgnlzd6qTi7LE1z2',
#    'id': '5Gm2XKBgnlzd6qTi7LE1z2',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730c5f23cbf0b1ab7e37d0dc67',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020c5f23cbf0b1ab7e37d0dc67',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510c5f23cbf0b1ab7e37d0dc67',
#      'width': 64}],
#    'name': 'Alone At Prom',
#    'release_date': '2021-12-10',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:5Gm2XKBgnlzd6qTi7LE1z2'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jku7tDXc6XoB6MO2hFuqg'},
#     'href': 'https://api.spotify.com/v1/artists/2jku7tDXc6XoB6MO2hFuqg',
#     'id': '2jku7tDXc6XoB6MO2hFuqg',
#     'name': 'Tory Lanez',
#     'type': 'artist',
#     'uri': 'spotify:artist:2jku7tDXc6XoB6MO2hFuqg'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 226466,
#   'explicit': False,
#   'external_ids': {'isrc': 'QZTGW2100275'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3azJifCSqg9fRij2yKIbWz'},
#   'href': 'https://api.spotify.com/v1/tracks/3azJifCSqg9fRij2yKIbWz',
#   'id': '3azJifCSqg9fRij2yKIbWz',
#   'is_local': False,
#   'name': 'The Color Violet',
#   'popularity': 90,
#   'preview_url': 'https://p.scdn.co/mp3-preview/1d7c627bf549328110519c4bd21ac39d7ca50ea1?cid=8e3b4a50b2ff4b929df3b7105c7850fb',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:3azJifCSqg9fRij2yKIbWz'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/77kULmXAQ6vWer7IIHdGzI'},
#      'href': 'https://api.spotify.com/v1/artists/77kULmXAQ6vWer7IIHdGzI',
#      'id': '77kULmXAQ6vWer7IIHdGzI',
#      'name': 'Jordan Davis',
#      'type': 'artist',
#      'uri': 'spotify:artist:77kULmXAQ6vWer7IIHdGzI'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2y9DFhTWC7QQJMvygK0TzO'},
#    'href': 'https://api.spotify.com/v1/albums/2y9DFhTWC7QQJMvygK0TzO',
#    'id': '2y9DFhTWC7QQJMvygK0TzO',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273dfdefe159fd457b152e9d367',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02dfdefe159fd457b152e9d367',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851dfdefe159fd457b152e9d367',
#      'width': 64}],
#    'name': 'Buy Dirt',
#    'release_date': '2021-05-21',
#    'release_date_precision': 'day',
#    'total_tracks': 8,
#    'type': 'album',
#    'uri': 'spotify:album:2y9DFhTWC7QQJMvygK0TzO'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/77kULmXAQ6vWer7IIHdGzI'},
#     'href': 'https://api.spotify.com/v1/artists/77kULmXAQ6vWer7IIHdGzI',
#     'id': '77kULmXAQ6vWer7IIHdGzI',
#     'name': 'Jordan Davis',
#     'type': 'artist',
#     'uri': 'spotify:artist:77kULmXAQ6vWer7IIHdGzI'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0BvkDsjIUla7X0k6CSWh1I'},
#     'href': 'https://api.spotify.com/v1/artists/0BvkDsjIUla7X0k6CSWh1I',
#     'id': '0BvkDsjIUla7X0k6CSWh1I',
#     'name': 'Luke Bryan',
#     'type': 'artist',
#     'uri': 'spotify:artist:0BvkDsjIUla7X0k6CSWh1I'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 167480,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM72104058'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/69AIpwGNLxr4qS1X5ynx60'},
#   'href': 'https://api.spotify.com/v1/tracks/69AIpwGNLxr4qS1X5ynx60',
#   'id': '69AIpwGNLxr4qS1X5ynx60',
#   'is_local': False,
#   'name': 'Buy Dirt',
#   'popularity': 84,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:69AIpwGNLxr4qS1X5ynx60'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#      'href': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM',
#      'id': '4oUHIQIBe0LHzYfvXNW4QM',
#      'name': 'Morgan Wallen',
#      'type': 'artist',
#      'uri': 'spotify:artist:4oUHIQIBe0LHzYfvXNW4QM'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6JlCkqkqobGirPsaleJpFr'},
#    'href': 'https://api.spotify.com/v1/albums/6JlCkqkqobGirPsaleJpFr',
#    'id': '6JlCkqkqobGirPsaleJpFr',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737d6813fd233f3bc4977cceca',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027d6813fd233f3bc4977cceca',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517d6813fd233f3bc4977cceca',
#      'width': 64}],
#    'name': 'Dangerous: The Double Album',
#    'release_date': '2021-01-08',
#    'release_date_precision': 'day',
#    'total_tracks': 30,
#    'type': 'album',
#    'uri': 'spotify:album:6JlCkqkqobGirPsaleJpFr'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#     'href': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM',
#     'id': '4oUHIQIBe0LHzYfvXNW4QM',
#     'name': 'Morgan Wallen',
#     'type': 'artist',
#     'uri': 'spotify:artist:4oUHIQIBe0LHzYfvXNW4QM'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 216573,
#   'explicit': False,
#   'external_ids': {'isrc': 'QZ22S1800117'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5OELUCYgOHKFAvCERnAvfS'},
#   'href': 'https://api.spotify.com/v1/tracks/5OELUCYgOHKFAvCERnAvfS',
#   'id': '5OELUCYgOHKFAvCERnAvfS',
#   'is_local': False,
#   'name': 'More Than My Hometown',
#   'popularity': 82,
#   'preview_url': None,
#   'track_number': 15,
#   'type': 'track',
#   'uri': 'spotify:track:5OELUCYgOHKFAvCERnAvfS'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5SXuuuRpukkTvsLuUknva1'},
#      'href': 'https://api.spotify.com/v1/artists/5SXuuuRpukkTvsLuUknva1',
#      'id': '5SXuuuRpukkTvsLuUknva1',
#      'name': 'Baby Keem',
#      'type': 'artist',
#      'uri': 'spotify:artist:5SXuuuRpukkTvsLuUknva1'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3r46DPIQeBQbjvjjV5mXGg'},
#    'href': 'https://api.spotify.com/v1/albums/3r46DPIQeBQbjvjjV5mXGg',
#    'id': '3r46DPIQeBQbjvjjV5mXGg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731bfa23b13d0504fb90c37b39',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021bfa23b13d0504fb90c37b39',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511bfa23b13d0504fb90c37b39',
#      'width': 64}],
#    'name': 'The Melodic Blue',
#    'release_date': '2021-09-10',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:3r46DPIQeBQbjvjjV5mXGg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5SXuuuRpukkTvsLuUknva1'},
#     'href': 'https://api.spotify.com/v1/artists/5SXuuuRpukkTvsLuUknva1',
#     'id': '5SXuuuRpukkTvsLuUknva1',
#     'name': 'Baby Keem',
#     'type': 'artist',
#     'uri': 'spotify:artist:5SXuuuRpukkTvsLuUknva1'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#     'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#     'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#     'name': 'Kendrick Lamar',
#     'type': 'artist',
#     'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 252262,
#   'explicit': True,
#   'external_ids': {'isrc': 'USSM12105949'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3QFInJAm9eyaho5vBzxInN'},
#   'href': 'https://api.spotify.com/v1/tracks/3QFInJAm9eyaho5vBzxInN',
#   'id': '3QFInJAm9eyaho5vBzxInN',
#   'is_local': False,
#   'name': 'family ties (with Kendrick Lamar)',
#   'popularity': 85,
#   'preview_url': 'https://p.scdn.co/mp3-preview/376965c332ef1da7f59826c2c12160456e960b8b?cid=8e3b4a50b2ff4b929df3b7105c7850fb',
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:3QFInJAm9eyaho5vBzxInN'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3SpBlxme9WbeQdI9kx7KAV'},
#    'href': 'https://api.spotify.com/v1/albums/3SpBlxme9WbeQdI9kx7KAV',
#    'id': '3SpBlxme9WbeQdI9kx7KAV',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273cd945b4e3de57edd28481a3f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02cd945b4e3de57edd28481a3f',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851cd945b4e3de57edd28481a3f',
#      'width': 64}],
#    'name': 'Certified Lover Boy',
#    'release_date': '2021-09-03',
#    'release_date_precision': 'day',
#    'total_tracks': 21,
#    'type': 'album',
#    'uri': 'spotify:album:3SpBlxme9WbeQdI9kx7KAV'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#     'id': '3TVXtAsR1Inumwj472S9r4',
#     'name': 'Drake',
#     'type': 'artist',
#     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'},
#     'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft',
#     'id': '1URnnhqYAYcrqrcwql10ft',
#     'name': '21 Savage',
#     'type': 'artist',
#     'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/08Ld63UgKrJ0nZnCkzHtzc'},
#     'href': 'https://api.spotify.com/v1/artists/08Ld63UgKrJ0nZnCkzHtzc',
#     'id': '08Ld63UgKrJ0nZnCkzHtzc',
#     'name': 'Project Pat',
#     'type': 'artist',
#     'uri': 'spotify:artist:08Ld63UgKrJ0nZnCkzHtzc'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 242965,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12104409'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2BcMwX1MPV6ZHP4tUT9uq6'},
#   'href': 'https://api.spotify.com/v1/tracks/2BcMwX1MPV6ZHP4tUT9uq6',
#   'id': '2BcMwX1MPV6ZHP4tUT9uq6',
#   'is_local': False,
#   'name': 'Knife Talk (with 21 Savage ft. Project Pat)',
#   'popularity': 85,
#   'preview_url': None,
#   'track_number': 13,
#   'type': 'track',
#   'uri': 'spotify:track:2BcMwX1MPV6ZHP4tUT9uq6'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5LuoozUhs2pl3glZeAJl89'},
#    'href': 'https://api.spotify.com/v1/albums/5LuoozUhs2pl3glZeAJl89',
#    'id': '5LuoozUhs2pl3glZeAJl89',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738b20e4631fa15d3953528bbc',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028b20e4631fa15d3953528bbc',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518b20e4631fa15d3953528bbc',
#      'width': 64}],
#    'name': 'Scary Hours 2',
#    'release_date': '2021-03-05',
#    'release_date_precision': 'day',
#    'total_tracks': 3,
#    'type': 'album',
#    'uri': 'spotify:album:5LuoozUhs2pl3glZeAJl89'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#     'id': '3TVXtAsR1Inumwj472S9r4',
#     'name': 'Drake',
#     'type': 'artist',
#     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5f7VJjfbwm532GiveGC0ZK'},
#     'href': 'https://api.spotify.com/v1/artists/5f7VJjfbwm532GiveGC0ZK',
#     'id': '5f7VJjfbwm532GiveGC0ZK',
#     'name': 'Lil Baby',
#     'type': 'artist',
#     'uri': 'spotify:artist:5f7VJjfbwm532GiveGC0ZK'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 192956,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12101042'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/65OVbaJR5O1RmwOQx0875b'},
#   'href': 'https://api.spotify.com/v1/tracks/65OVbaJR5O1RmwOQx0875b',
#   'id': '65OVbaJR5O1RmwOQx0875b',
#   'is_local': False,
#   'name': 'Wants and Needs (feat. Lil Baby)',
#   'popularity': 84,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:65OVbaJR5O1RmwOQx0875b'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3SpBlxme9WbeQdI9kx7KAV'},
#    'href': 'https://api.spotify.com/v1/albums/3SpBlxme9WbeQdI9kx7KAV',
#    'id': '3SpBlxme9WbeQdI9kx7KAV',
#    'images': [{'height': 640,
# ...
#     'SC',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4QLAtpLNUsHEYrcHXmMIZZ'},
#    'href': 'https://api.spotify.com/v1/albums/4QLAtpLNUsHEYrcHXmMIZZ',
#    'id': '4QLAtpLNUsHEYrcHXmMIZZ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27341e31d6ea1d493dd77933ee5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0241e31d6ea1d493dd77933ee5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485141e31d6ea1d493dd77933ee5',
#      'width': 64}],
#    'name': 'STAY (with Justin Bieber)',
#    'release_date': '2021-07-09',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:4QLAtpLNUsHEYrcHXmMIZZ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tIP7SsRs7vjIcLrU85W8J'},
#     'href': 'https://api.spotify.com/v1/artists/2tIP7SsRs7vjIcLrU85W8J',
#     'id': '2tIP7SsRs7vjIcLrU85W8J',
#     'name': 'The Kid LAROI',
#     'type': 'artist',
#     'uri': 'spotify:artist:2tIP7SsRs7vjIcLrU85W8J'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#     'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#     'id': '1uNFoZAHBGtllmzznpCI3s',
#     'name': 'Justin Bieber',
#     'type': 'artist',
#     'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 141805,
#   'explicit': True,
#   'external_ids': {'isrc': 'USSM12103949'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5HCyWlXZPP0y6Gqq8TgA20'},
#   'href': 'https://api.spotify.com/v1/tracks/5HCyWlXZPP0y6Gqq8TgA20',
#   'id': '5HCyWlXZPP0y6Gqq8TgA20',
#   'is_local': False,
#   'name': 'STAY (with Justin Bieber)',
#   'popularity': 88,
#   'preview_url': 'https://p.scdn.co/mp3-preview/718a2eb032524494a01f73d80af2bcf176c9f3e2?cid=8e3b4a50b2ff4b929df3b7105c7850fb',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:5HCyWlXZPP0y6Gqq8TgA20'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#      'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#      'id': '5cj0lLjcoR7YOSnhnX0Po5',
#      'name': 'Doja Cat',
#      'type': 'artist',
#      'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1nAQbHeOWTfQzbOoFrvndW'},
#    'href': 'https://api.spotify.com/v1/albums/1nAQbHeOWTfQzbOoFrvndW',
#    'id': '1nAQbHeOWTfQzbOoFrvndW',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734df3245f26298a1579ecc321',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024df3245f26298a1579ecc321',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514df3245f26298a1579ecc321',
#      'width': 64}],
#    'name': 'Planet Her',
#    'release_date': '2021-06-25',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:1nAQbHeOWTfQzbOoFrvndW'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#     'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#     'id': '5cj0lLjcoR7YOSnhnX0Po5',
#     'name': 'Doja Cat',
#     'type': 'artist',
#     'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#     'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#     'id': '7tYKF4w9nC0nq9CsPZTHyP',
#     'name': 'SZA',
#     'type': 'artist',
#     'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 208666,
#   'explicit': True,
#   'external_ids': {'isrc': 'USRC12100543'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3DarAbFujv6eYNliUTyqtz'},
#   'href': 'https://api.spotify.com/v1/tracks/3DarAbFujv6eYNliUTyqtz',
#   'id': '3DarAbFujv6eYNliUTyqtz',
#   'is_local': False,
#   'name': 'Kiss Me More (feat. SZA)',
#   'popularity': 84,
#   'preview_url': 'https://p.scdn.co/mp3-preview/2903cc27c1a5bd03f247a7f83ace394c36d3c75f?cid=8e3b4a50b2ff4b929df3b7105c7850fb',
#   'track_number': 14,
#   'type': 'track',
#   'uri': 'spotify:track:3DarAbFujv6eYNliUTyqtz'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#      'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#      'id': '64KEffDW9EtZ1y2vBYgq8T',
#      'name': 'Marshmello',
#      'type': 'artist',
#      'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#      'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#      'id': '7gOdHgIoIKoe4i9Tta6qdD',
#      'name': 'Jonas Brothers',
#      'type': 'artist',
#      'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/66JuK41D3LpkbX3HCTGcQk'},
#    'href': 'https://api.spotify.com/v1/albums/66JuK41D3LpkbX3HCTGcQk',
#    'id': '66JuK41D3LpkbX3HCTGcQk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ae40468931087f78919b86ce',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ae40468931087f78919b86ce',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ae40468931087f78919b86ce',
#      'width': 64}],
#    'name': 'Leave Before You Love Me',
#    'release_date': '2021-05-21',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:66JuK41D3LpkbX3HCTGcQk'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#     'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#     'id': '64KEffDW9EtZ1y2vBYgq8T',
#     'name': 'Marshmello',
#     'type': 'artist',
#     'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#     'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#     'id': '7gOdHgIoIKoe4i9Tta6qdD',
#     'name': 'Jonas Brothers',
#     'type': 'artist',
#     'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 154983,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG12102313'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4qu63nuBpdn0qHUHuObEj1'},
#   'href': 'https://api.spotify.com/v1/tracks/4qu63nuBpdn0qHUHuObEj1',
#   'id': '4qu63nuBpdn0qHUHuObEj1',
#   'is_local': False,
#   'name': 'Leave Before You Love Me (with Jonas Brothers)',
#   'popularity': 86,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:4qu63nuBpdn0qHUHuObEj1'}]

# %%
# track_id
t[0]["id"]
# Out:
# '3cBsEDNhFI9E82vPj3kvi3'

# %%
# track_name
t[0]["name"]
# Out:
# 'Wasted On You'

# %%
# track_popularity
t[0]["popularity"]
# Out:
# 88

# %%
# artist_name
t[0]["artists"][0]["name"]
# Out:
# 'Morgan Wallen'

# %%
# function to get track info from the search
def get_tracks(to_search):
    track_id = []
    track_name = []
    track_popularity = []
    artist_id = []
    artist_name = []
    
    for i in (range(0,1000,50)):
        search = sp.search(q= to_search, type="track", limit=50, offset = i)
        for i, t in enumerate(search['tracks']['items']):
            track_id.append(t["id"])
            track_name.append(t["name"])
            track_popularity.append(t["popularity"])
            artist_name.append(t["artists"][0]['name'])
            artist_id.append(t["artists"][0]['id'])

    
    dict = {"track_id": track_id, "track_name": track_name, "track_popularity": track_popularity, "artist_id": artist_id, "artist_name": artist_name}
            
    return dict

# %% [markdown]
# **We will get add songs from 2020 to 2023 to the full song list from kaggle.**

# %%
latest_songs = pd.DataFrame()
for i in list(["year 2020", "year 2021", "year 2022", "year 2023"]):
    y = get_tracks(i)
    new_df = pd.DataFrame.from_dict(y)
    latest_songs = pd.concat([latest_songs, new_df])

# %%
latest_songs.head()
# Out:
#                  track_id           track_name  track_popularity
# 0  0MlkZnfwsjwHHSfn07N8ao  Longest Year (2020)                19  \
# 1  4vaSRWOwLipBtCKPNL31WV            Year 2020                10
# 2  0t2q2c43AATY4z1GI883Be          Summer 2020                56
# 3  0qSXoNHcm1sn9kWcAG7WCx     Ghosts N Goblins                25
# 4  6dEPod8uKS1oqcD7RZYy6c            Year 2020                 5
#
#                 artist_id      artist_name
# 0  0VOR7Ie9xUSb45fzIIVJQ1          Hammock
# 1  1edCXsyYTTXcwtSIdsTAzb           Razinn
# 2  5ZS223C6JyBfXasXxrRqOk       Jhené Aiko
# 3  6JMGrupbzJZ3yuQhTGyeHr        Year 200X
# 4  3p18oCfd7ERzBpfjjFArjV  Ruined Conflict

# %%
latest_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          4000 non-null   object
#  1   track_name        4000 non-null   object
#  2   track_popularity  4000 non-null   int64
#  3   artist_id         4000 non-null   object
#  4   artist_name       4000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 187.5+ KB

# %%
latest_songs.duplicated().sum()
# Out:
# 1027

# %%
latest = latest_songs.drop_duplicates()

# %%
latest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2973 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          2973 non-null   object
#  1   track_name        2973 non-null   object
#  2   track_popularity  2973 non-null   int64
#  3   artist_id         2973 non-null   object
#  4   artist_name       2973 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 139.4+ KB

# %% [markdown]
# ### GET AUDIO FEATURES OF LATEST SONGS

# %%
def audio_features(track_ids_list):
    audio_features = pd.DataFrame()
    for i, o in zip(range(0, (len(track_ids_list)+100), 100), range(100, (len(track_ids_list)+100), 100)):
        try:
            features = sp.audio_features(track_ids_list[i:o])
            features_df = pd.DataFrame(features)
            audio_features = pd.concat([audio_features, features_df])
        except AttributeError:
            pass
    return audio_features

# %%
audio_feat = audio_features(latest.track_id)

# %%
audio_feat
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness
# 0         0.0705  0.2860    2   -14.865     1       0.0444      0.685000  \
# 1         0.4150  0.0287    6   -27.175     0       0.0360      0.859000
# 2         0.4010  0.4850    6   -10.787     0       0.2160      0.831000
# 3         0.2940  0.7880    7    -8.439     1       0.0441      0.000004
# 4         0.4050  0.6880    1    -7.562     1       0.0359      0.000947
# ..           ...     ...  ...       ...   ...          ...           ...
# 68        0.4300  0.8680    9    -4.469     1       0.0358      0.629000
# 69        0.5700  0.8980    6    -2.956     1       0.0865      0.146000
# 70        0.1740  0.5020    2   -15.824     1       0.0501      0.082500
# 71        0.5220  0.5800    7    -9.652     1       0.2560      0.630000
# 72        0.7440  0.8570    0    -7.005     0       0.0906      0.102000
#
#     instrumentalness  liveness  valence    tempo            type
# 0           0.675000    0.1870   0.0313   78.251  audio_features  \
# 1           0.851000    0.1080   0.0601  115.058  audio_features
# 2           0.000292    0.0907   0.5400  169.949  audio_features
# 3           0.967000    0.0681   0.5410   93.028  audio_features
# 4           0.637000    0.1880   0.0615  140.027  audio_features
# ..               ...       ...      ...      ...             ...
# 68          0.000549    0.4010   0.6330   82.504  audio_features
# 69          0.000000    0.1310   0.9620  188.057  audio_features
# 70          0.000162    0.4730   0.2950  134.060  audio_features
# 71          0.000002    0.7030   0.7100  129.106  audio_features
# 72          0.020400    0.1040   0.9100  126.001  audio_features
#
#                         id                                   uri
# 0   0MlkZnfwsjwHHSfn07N8ao  spotify:track:0MlkZnfwsjwHHSfn07N8ao  \
# 1   4vaSRWOwLipBtCKPNL31WV  spotify:track:4vaSRWOwLipBtCKPNL31WV
# 2   0t2q2c43AATY4z1GI883Be  spotify:track:0t2q2c43AATY4z1GI883Be
# 3   0qSXoNHcm1sn9kWcAG7WCx  spotify:track:0qSXoNHcm1sn9kWcAG7WCx
# 4   6dEPod8uKS1oqcD7RZYy6c  spotify:track:6dEPod8uKS1oqcD7RZYy6c
# ..                     ...                                   ...
# 68  1O276eC6ltdMUKlOIvJQLh  spotify:track:1O276eC6ltdMUKlOIvJQLh
# 69  6Cl8ej1NqfeFKHIwnzSjEc  spotify:track:6Cl8ej1NqfeFKHIwnzSjEc
# 70  0HXW1L4rvRh4Ihib3RuTdK  spotify:track:0HXW1L4rvRh4Ihib3RuTdK
# 71  4Rk6lzJ6WS1dIxv8FyanLK  spotify:track:4Rk6lzJ6WS1dIxv8FyanLK
# 72  4rtQ2oOVQZyQmFKjAFs44X  spotify:track:4rtQ2oOVQZyQmFKjAFs44X
#
#                                            track_href
# 0   https://api.spotify.com/v1/tracks/0MlkZnfwsjwH...  \
# 1   https://api.spotify.com/v1/tracks/4vaSRWOwLipB...
# 2   https://api.spotify.com/v1/tracks/0t2q2c43AATY...
# 3   https://api.spotify.com/v1/tracks/0qSXoNHcm1sn...
# 4   https://api.spotify.com/v1/tracks/6dEPod8uKS1o...
# ..                                                ...
# 68  https://api.spotify.com/v1/tracks/1O276eC6ltdM...
# 69  https://api.spotify.com/v1/tracks/6Cl8ej1NqfeF...
# 70  https://api.spotify.com/v1/tracks/0HXW1L4rvRh4...
# 71  https://api.spotify.com/v1/tracks/4Rk6lzJ6WS1d...
# 72  https://api.spotify.com/v1/tracks/4rtQ2oOVQZyQ...
#
#                                          analysis_url  duration_ms
# 0   https://api.spotify.com/v1/audio-analysis/0Mlk...       533707  \
# 1   https://api.spotify.com/v1/audio-analysis/4vaS...        82299
# 2   https://api.spotify.com/v1/audio-analysis/0t2q...       196000
# 3   https://api.spotify.com/v1/audio-analysis/0qSX...       106973
# 4   https://api.spotify.com/v1/audio-analysis/6dEP...       264000
# ..                                                ...          ...
# 68  https://api.spotify.com/v1/audio-analysis/1O27...       102111
# 69  https://api.spotify.com/v1/audio-analysis/6Cl8...       179427
# 70  https://api.spotify.com/v1/audio-analysis/0HXW...       132000
# 71  https://api.spotify.com/v1/audio-analysis/4Rk6...       227367
# 72  https://api.spotify.com/v1/audio-analysis/4rtQ...       400000
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 68               4
# 69               4
# 70               4
# 71               4
# 72               4
#
# [2773 rows x 18 columns]

# %%
cols_to_drop = ['type', 'uri', 'analysis_url', 'time_signature']
audio_features = audio_feat.drop(columns=cols_to_drop)

# %%
audio_features.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness
# 0        0.0705  0.2860    2   -14.865     1       0.0444      0.685000  \
# 1        0.4150  0.0287    6   -27.175     0       0.0360      0.859000
# 2        0.4010  0.4850    6   -10.787     0       0.2160      0.831000
# 3        0.2940  0.7880    7    -8.439     1       0.0441      0.000004
# 4        0.4050  0.6880    1    -7.562     1       0.0359      0.000947
#
#    instrumentalness  liveness  valence    tempo                      id
# 0          0.675000    0.1870   0.0313   78.251  0MlkZnfwsjwHHSfn07N8ao  \
# 1          0.851000    0.1080   0.0601  115.058  4vaSRWOwLipBtCKPNL31WV
# 2          0.000292    0.0907   0.5400  169.949  0t2q2c43AATY4z1GI883Be
# 3          0.967000    0.0681   0.5410   93.028  0qSXoNHcm1sn9kWcAG7WCx
# 4          0.637000    0.1880   0.0615  140.027  6dEPod8uKS1oqcD7RZYy6c
#
#                                           track_href  duration_ms
# 0  https://api.spotify.com/v1/tracks/0MlkZnfwsjwH...       533707
# 1  https://api.spotify.com/v1/tracks/4vaSRWOwLipB...        82299
# 2  https://api.spotify.com/v1/tracks/0t2q2c43AATY...       196000
# 3  https://api.spotify.com/v1/tracks/0qSXoNHcm1sn...       106973
# 4  https://api.spotify.com/v1/tracks/6dEPod8uKS1o...       264000

# %%
# merge audio features with track infos
full_latest = latest.merge(audio_features, left_on = "track_id", right_on = "id")

# %%
# save to csv for safeguarding
#full_latest.to_csv('songs_2020-3.csv', index=False)

# %%
# drop some redundant columns
connect = full_latest.drop(columns=["id", "artist_id"])

# %%
connect
# Out:
#                     track_id
# 0     0MlkZnfwsjwHHSfn07N8ao  \
# 1     4vaSRWOwLipBtCKPNL31WV
# 2     0t2q2c43AATY4z1GI883Be
# 3     0qSXoNHcm1sn9kWcAG7WCx
# 4     6dEPod8uKS1oqcD7RZYy6c
# ...                      ...
# 2768  1O276eC6ltdMUKlOIvJQLh
# 2769  6Cl8ej1NqfeFKHIwnzSjEc
# 2770  0HXW1L4rvRh4Ihib3RuTdK
# 2771  4Rk6lzJ6WS1dIxv8FyanLK
# 2772  4rtQ2oOVQZyQmFKjAFs44X
#
#                                             track_name  track_popularity
# 0                                  Longest Year (2020)                19  \
# 1                                            Year 2020                10
# 2                                          Summer 2020                56
# 3                                     Ghosts N Goblins                25
# 4                                            Year 2020                 5
# ...                                                ...               ...
# 2768                Traditional Chinese New Year Music                 0
# 2769                    Christmas the Whole Year Round                 2
# 2770  Drown Cold Water Blues - 2023 Remastered Version                 0
# 2771       2023 - Live at E54, West Chester, 12/8/2018                 0
# 2772  Far Away - Groove Junkies Main Mix 2023 Remaster                 0
#
#                artist_name  danceability  energy  key  loudness  mode
# 0                  Hammock        0.0705  0.2860    2   -14.865     1  \
# 1                   Razinn        0.4150  0.0287    6   -27.175     0
# 2               Jhené Aiko        0.4010  0.4850    6   -10.787     0
# 3                Year 200X        0.2940  0.7880    7    -8.439     1
# 4          Ruined Conflict        0.4050  0.6880    1    -7.562     1
# ...                    ...           ...     ...  ...       ...   ...
# 2768   Kyrylo Zaplotynskyi        0.4300  0.8680    9    -4.469     1
# 2769     Sabrina Carpenter        0.5700  0.8980    6    -2.956     1
# 2770            telesphore        0.1740  0.5020    2   -15.824     1
# 2771  The Kitchen Thimbles        0.5220  0.5800    7    -9.652     1
# 2772        Groove Junkies        0.7440  0.8570    0    -7.005     0
#
#       speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0          0.0444      0.685000          0.675000    0.1870   0.0313   78.251  \
# 1          0.0360      0.859000          0.851000    0.1080   0.0601  115.058
# 2          0.2160      0.831000          0.000292    0.0907   0.5400  169.949
# 3          0.0441      0.000004          0.967000    0.0681   0.5410   93.028
# 4          0.0359      0.000947          0.637000    0.1880   0.0615  140.027
# ...           ...           ...               ...       ...      ...      ...
# 2768       0.0358      0.629000          0.000549    0.4010   0.6330   82.504
# 2769       0.0865      0.146000          0.000000    0.1310   0.9620  188.057
# 2770       0.0501      0.082500          0.000162    0.4730   0.2950  134.060
# 2771       0.2560      0.630000          0.000002    0.7030   0.7100  129.106
# 2772       0.0906      0.102000          0.020400    0.1040   0.9100  126.001
#
#                                              track_href  duration_ms
# 0     https://api.spotify.com/v1/tracks/0MlkZnfwsjwH...       533707
# 1     https://api.spotify.com/v1/tracks/4vaSRWOwLipB...        82299
# 2     https://api.spotify.com/v1/tracks/0t2q2c43AATY...       196000
# 3     https://api.spotify.com/v1/tracks/0qSXoNHcm1sn...       106973
# 4     https://api.spotify.com/v1/tracks/6dEPod8uKS1o...       264000
# ...                                                 ...          ...
# 2768  https://api.spotify.com/v1/tracks/1O276eC6ltdM...       102111
# 2769  https://api.spotify.com/v1/tracks/6Cl8ej1NqfeF...       179427
# 2770  https://api.spotify.com/v1/tracks/0HXW1L4rvRh4...       132000
# 2771  https://api.spotify.com/v1/tracks/4Rk6lzJ6WS1d...       227367
# 2772  https://api.spotify.com/v1/tracks/4rtQ2oOVQZyQ...       400000
#
# [2773 rows x 17 columns]

# %%
connect.shape # this dataframe has more columns so we will definitely drop some more to have the same attributes as the 160k songs
# Out:
# (2773, 17)

# %%
connect.columns
# Out:
# Index(['track_id', 'track_name', 'track_popularity', 'artist_name',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'track_href', 'duration_ms'],
#       dtype='object')

# %%
concat = connect.drop(["track_href", "track_popularity"], axis=1)
concat.shape # now we have the same number of columns. we can proceed to concatenating the dataframes
# Out:
# (2773, 15)

# %%
list_cols = list(concat.columns) # columns to keep. we will use these to make sure we have the same columns from the df160k dataset
list_cols
# Out:
# ['track_id',
#  'track_name',
#  'artist_name',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms']

# %% [markdown]
# ### KAGGLE 160K DATASET

# %%
df_160k = pd.read_csv('160k_data.csv') # list of songs from kaggle from 1921 to june 2020
df_160k
# Out:
#                             id
# 0       0gNNToCW3qjabgTyBSjt3H  \
# 1       0tMgFpOrXZR6irEOLNWwJL
# 2       2ZywW3VyVx6rrlrX75n3JB
# 3       6DdWA7D1o5TU2kXWyCLcch
# 4       3vMmwsAiLDCfyc1jl76lQE
# ...                        ...
# 169902  4KiYPYpm4ultIp247ftPlI
# 169903  42tFTth2jcF7iSo0RBjfJF
# 169904  6XP9L7di5JnOc9WaeAW8oe
# 169905  3Gpdzw72aBVJSrm5J1leVK
# 169906  2p5DfmIUTLH79elmaSCCR5
#
#                                                      name
# 0                               !Que Vida! - Mono Version  \
# 1                                                    "40"
# 2                                             "40" - Live
# 3                                  "40" - Remastered 2008
# 4                                  "40" - Remastered 2008
# ...                                                   ...
# 169902                                 텅 빈 마음 Empty Heart
# 169903                                     피카부 Peek-A-Boo
# 169904                                     행복 (Happiness)
# 169905  헤어지지 못하는 여자, 떠나가지 못하는 남자 Can't Breakup Girl, C...
# 169906                화려하지 않은 고백 Confession Is Not Flashy
#
#                         artists  duration_ms release_date  year  acousticness
# 0                      ['Love']       220560      11/1/66  1966        0.5250  \
# 1                        ['U2']       157840      2/28/83  1983        0.2280
# 2                        ['U2']       226200      8/20/83  1983        0.0998
# 3                        ['U2']       157667      2/28/83  1983        0.1850
# 4                        ['U2']       157667      2/28/83  1983        0.1850
# ...                         ...          ...          ...   ...           ...
# 169902       ['LEE SEUNG HWAN']       249893     10/15/89  1989        0.4290
# 169903           ['Red Velvet']       189050     11/17/17  2017        0.0868
# 169904           ['Red Velvet']       220987       8/1/14  2014        0.3230
# 169905  ['Leessang', 'Jung In']       284627      10/6/09  2009        0.1500
# 169906       ['LEE SEUNG HWAN']       230733       9/1/93  1993        0.4480
#
#         danceability  energy  instrumentalness  liveness  loudness
# 0              0.600   0.540          0.003050    0.1000   -11.803  \
# 1              0.368   0.480          0.707000    0.1590   -11.605
# 2              0.272   0.684          0.014500    0.9460    -9.728
# 3              0.371   0.545          0.582000    0.1830    -9.315
# 4              0.371   0.545          0.582000    0.1830    -9.315
# ...              ...     ...               ...       ...       ...
# 169902         0.547   0.304          0.000000    0.1430   -14.326
# 169903         0.839   0.902          0.002570    0.2720    -3.612
# 169904         0.727   0.871          0.000006    0.7250    -3.099
# 169905         0.523   0.841          0.000000    0.1640    -2.505
# 169906         0.741   0.380          0.000811    0.0806    -9.539
#
#         speechiness    tempo  valence  mode  key  popularity  explicit
# 0            0.0328  125.898    0.547     1    9          26         0
# 1            0.0306  150.166    0.338     1    8          21         0
# 2            0.0505  143.079    0.279     1    8          41         0
# 3            0.0307  150.316    0.310     1    8          37         0
# 4            0.0307  150.316    0.310     1    8          35         0
# ...             ...      ...      ...   ...  ...         ...       ...
# 169902       0.0336   74.164    0.157     0   11          35         0
# 169903       0.0536  114.953    0.639     0    1          69         0
# 169904       0.1580  121.438    0.681     0   10          58         0
# 169905       0.3310  173.903    0.383     0   10          52         0
# 169906       0.0285  101.971    0.264     1    2          43         0
#
# [169907 rows x 19 columns]

# %%
# check columns
df_160k.columns
# Out:
# Index(['id', 'name', 'artists', 'duration_ms', 'release_date', 'year',
#        'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'mode',
#        'key', 'popularity', 'explicit'],
#       dtype='object')

# %%
# rename columns to have the same as the latest songs dataset
df_160k.columns = ['track_id', 'track_name', 'artist_name', 'duration_ms', 'release_date', 'year',
       'acousticness', 'danceability', 'energy', 'instrumentalness',
       'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'mode',
       'key', 'track_popularity', 'explicit']

# %%
# new df with the same columns as the concat df
spotify_160k = df_160k[list_cols]
spotify_160k.head()
# Out:
#                  track_id                 track_name artist_name
# 0  0gNNToCW3qjabgTyBSjt3H  !Que Vida! - Mono Version    ['Love']  \
# 1  0tMgFpOrXZR6irEOLNWwJL                       "40"      ['U2']
# 2  2ZywW3VyVx6rrlrX75n3JB                "40" - Live      ['U2']
# 3  6DdWA7D1o5TU2kXWyCLcch     "40" - Remastered 2008      ['U2']
# 4  3vMmwsAiLDCfyc1jl76lQE     "40" - Remastered 2008      ['U2']
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness
# 0         0.600   0.540    9   -11.803     1       0.0328        0.5250  \
# 1         0.368   0.480    8   -11.605     1       0.0306        0.2280
# 2         0.272   0.684    8    -9.728     1       0.0505        0.0998
# 3         0.371   0.545    8    -9.315     1       0.0307        0.1850
# 4         0.371   0.545    8    -9.315     1       0.0307        0.1850
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0           0.00305     0.100    0.547  125.898       220560
# 1           0.70700     0.159    0.338  150.166       157840
# 2           0.01450     0.946    0.279  143.079       226200
# 3           0.58200     0.183    0.310  150.316       157667
# 4           0.58200     0.183    0.310  150.316       157667

# %% [markdown]
# ### PLAYLIST TRACKS FROM PREVIOUS LAB

# %%
playlist_tracks = pd.read_csv('full_df_playlists.csv')
playlist_tracks.drop(['artist_id', 'id', 'time_signature'], axis=1, inplace=True)

# %%
playlist_tracks.head()
# Out:
#                  track_id                    track                    artist
# 0  5ghIJDpPoe3CfHMGu71E6T  Smells Like Teen Spirit                   Nirvana  \
# 1  1FkoVC85Ds3mFoK0fVqEqP              Self Esteem             The Offspring
# 2  59WN2psjkt1tyaxjspN8fp      Killing In The Name  Rage Against The Machine
# 3  6L89mwZXSOwYl76YXfX13s              Basket Case                 Green Day
# 4  3d9DChrdc6BOeFsbrZ3Is0         Under the Bridge     Red Hot Chili Peppers
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness
# 0         0.502   0.912    1    -4.556     1       0.0564      0.000025  \
# 1         0.488   0.862    0    -7.595     1       0.0476      0.020400
# 2         0.466   0.833    7    -4.215     1       0.3040      0.026600
# 3         0.442   0.943    3    -3.205     1       0.0602      0.002930
# 4         0.559   0.345    4   -13.496     1       0.0459      0.057600
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000173    0.1060    0.720  116.761       301920
# 1          0.000000    0.3590    0.706  104.560       257827
# 2          0.000000    0.0327    0.661   88.785       313573
# 3          0.000009    0.0910    0.781   85.064       181533
# 4          0.000105    0.1410    0.458   84.581       264307

# %%
playlist_tracks.columns = ['track_id', 'track_name', 'artist_name', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'duration_ms']

# %%
# putting all the tracks together
tracks_features = pd.concat([spotify_160k, concat, playlist_tracks])
tracks_features # we now have over 174K tracks. we need to check for any duplicates and null values
# Out:
#                     track_id                     track_name     artist_name
# 0     0gNNToCW3qjabgTyBSjt3H      !Que Vida! - Mono Version        ['Love']  \
# 1     0tMgFpOrXZR6irEOLNWwJL                           "40"          ['U2']
# 2     2ZywW3VyVx6rrlrX75n3JB                    "40" - Live          ['U2']
# 3     6DdWA7D1o5TU2kXWyCLcch         "40" - Remastered 2008          ['U2']
# 4     3vMmwsAiLDCfyc1jl76lQE         "40" - Remastered 2008          ['U2']
# ...                      ...                            ...             ...
# 1698  3d0VZU6Mf2hdZRHA4zry8S                     John Wayne       Lady Gaga
# 1699  4de1X6v99U7tfOXrNUCTbi                          Candy        Doja Cat
# 1700  1GVF9369j7InydwGztCDIZ                Good In Goodbye    Madison Beer
# 1701  6qNB2ChCVPepl5ZjVJJTUW  STUPID (feat. Yung Baby Tate)        Ashnikko
# 1702  1YrgbwVse66pH7ysXLlgO8               Heartbreak Hotel  Abigail Barlow
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness
# 0            0.600   0.540    9   -11.803     1       0.0328       0.52500  \
# 1            0.368   0.480    8   -11.605     1       0.0306       0.22800
# 2            0.272   0.684    8    -9.728     1       0.0505       0.09980
# 3            0.371   0.545    8    -9.315     1       0.0307       0.18500
# 4            0.371   0.545    8    -9.315     1       0.0307       0.18500
# ...            ...     ...  ...       ...   ...          ...           ...
# 1698         0.610   0.667   11    -5.825     0       0.0314       0.00131
# 1699         0.689   0.516    8    -5.857     1       0.0444       0.51300
# 1700         0.658   0.698   11    -5.950     0       0.1770       0.43300
# 1701         0.772   0.637    2    -6.881     1       0.1140       0.00459
# 1702         0.639   0.837    1    -5.445     1       0.0849       0.13900
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.003050    0.1000    0.547  125.898       220560
# 1             0.707000    0.1590    0.338  150.166       157840
# 2             0.014500    0.9460    0.279  143.079       226200
# 3             0.582000    0.1830    0.310  150.316       157667
# 4             0.582000    0.1830    0.310  150.316       157667
# ...                ...       ...      ...      ...          ...
# 1698          0.000180    0.3400    0.510   96.954       174307
# 1699          0.000000    0.1680    0.209  124.876       190907
# 1700          0.000000    0.1740    0.456  139.054       141949
# 1701          0.000000    0.0778    0.540  149.906       167317
# 1702          0.000001    0.3010    0.621  167.161       196325
#
# [174383 rows x 15 columns]

# %%
# clean artist_name column by removing special characters
tracks_features.artist_name = tracks_features.artist_name.apply(lambda x: x.translate({ord(i): None for i in """['"]"""}))

# %%
tracks_features
# Out:
#                     track_id                     track_name     artist_name
# 0     0gNNToCW3qjabgTyBSjt3H      !Que Vida! - Mono Version            Love  \
# 1     0tMgFpOrXZR6irEOLNWwJL                           "40"              U2
# 2     2ZywW3VyVx6rrlrX75n3JB                    "40" - Live              U2
# 3     6DdWA7D1o5TU2kXWyCLcch         "40" - Remastered 2008              U2
# 4     3vMmwsAiLDCfyc1jl76lQE         "40" - Remastered 2008              U2
# ...                      ...                            ...             ...
# 1698  3d0VZU6Mf2hdZRHA4zry8S                     John Wayne       Lady Gaga
# 1699  4de1X6v99U7tfOXrNUCTbi                          Candy        Doja Cat
# 1700  1GVF9369j7InydwGztCDIZ                Good In Goodbye    Madison Beer
# 1701  6qNB2ChCVPepl5ZjVJJTUW  STUPID (feat. Yung Baby Tate)        Ashnikko
# 1702  1YrgbwVse66pH7ysXLlgO8               Heartbreak Hotel  Abigail Barlow
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness
# 0            0.600   0.540    9   -11.803     1       0.0328       0.52500  \
# 1            0.368   0.480    8   -11.605     1       0.0306       0.22800
# 2            0.272   0.684    8    -9.728     1       0.0505       0.09980
# 3            0.371   0.545    8    -9.315     1       0.0307       0.18500
# 4            0.371   0.545    8    -9.315     1       0.0307       0.18500
# ...            ...     ...  ...       ...   ...          ...           ...
# 1698         0.610   0.667   11    -5.825     0       0.0314       0.00131
# 1699         0.689   0.516    8    -5.857     1       0.0444       0.51300
# 1700         0.658   0.698   11    -5.950     0       0.1770       0.43300
# 1701         0.772   0.637    2    -6.881     1       0.1140       0.00459
# 1702         0.639   0.837    1    -5.445     1       0.0849       0.13900
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.003050    0.1000    0.547  125.898       220560
# 1             0.707000    0.1590    0.338  150.166       157840
# 2             0.014500    0.9460    0.279  143.079       226200
# 3             0.582000    0.1830    0.310  150.316       157667
# 4             0.582000    0.1830    0.310  150.316       157667
# ...                ...       ...      ...      ...          ...
# 1698          0.000180    0.3400    0.510   96.954       174307
# 1699          0.000000    0.1680    0.209  124.876       190907
# 1700          0.000000    0.1740    0.456  139.054       141949
# 1701          0.000000    0.0778    0.540  149.906       167317
# 1702          0.000001    0.3010    0.621  167.161       196325
#
# [174383 rows x 15 columns]

# %%
# check missing values
tracks_features.isna().sum() # there are none. YAY!
# Out:
# track_id            0
# track_name          0
# artist_name         0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# dtype: int64

# %%
# checking for duplicates
tracks_features.duplicated().sum() # some duplicates were found.
# Out:
# 343

# %%
# remove duplicates
tracks_features = tracks_features.drop_duplicates()
tracks_features.shape
# Out:
# (174040, 15)

# %%
tracks_features[tracks_features.track_name == "Smells Like Teen Spirit"] # a problem encountered: I can definitely see duplicates but they have different track_ids!
# Out:
#                       track_id               track_name artist_name
# 124213  2Wtm3yc0paBifvBSjOhO3b  Smells Like Teen Spirit     Nirvana  \
# 124214  6y1etHPLRsgA467gLBOgBm  Smells Like Teen Spirit     Nirvana
# 124215  5ghIJDpPoe3CfHMGu71E6T  Smells Like Teen Spirit     Nirvana
# 124216  56Cub3qT0VhFQd2Wiblv2w  Smells Like Teen Spirit     Nirvana
# 124217  75aLTVBSGIquqzQ6AkmK3Q  Smells Like Teen Spirit     Nirvana
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness
# 124213         0.502   0.912    1    -4.556     1       0.0564      0.000025  \
# 124214         0.479   0.873    1    -5.896     1       0.0438      0.000014
# 124215         0.502   0.912    1    -4.556     1       0.0564      0.000025
# 124216         0.502   0.912    1    -4.556     1       0.0564      0.000025
# 124217         0.502   0.912    1    -4.556     1       0.0564      0.000025
#
#         instrumentalness  liveness  valence    tempo  duration_ms
# 124213          0.000173    0.1060    0.720  116.761       301920
# 124214          0.000565    0.0974    0.816  116.710       301453
# 124215          0.000173    0.1060    0.720  116.761       301920
# 124216          0.000173    0.1060    0.720  116.761       301920
# 124217          0.000173    0.1060    0.720  116.761       301920

# %% [markdown]
# **Not sure if I'll have time to re-check which track_id is the correct one so this will be left alone for now.**

# %%
# saving the full tracks list to csv for safeguarding and the next step of the song recommendation project
#tracks_features.to_csv('final_full_list2.csv', index=False)
