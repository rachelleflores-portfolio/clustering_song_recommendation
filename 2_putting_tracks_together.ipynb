# %% [markdown]
# # Putting spotify tracks together

# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import config

# %% [markdown]
# ### SPOTIPY CONNECTION

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=config.client_id, client_secret=config.client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, requests_timeout=120)

# %%
# CHECK SEARCH RESULTS
h = sp.search(q='year:2021', type='track', limit=50)

# %%
t= h["tracks"]["items"]

# %%
t
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5SXuuuRpukkTvsLuUknva1'},
#      'href': 'https://api.spotify.com/v1/artists/5SXuuuRpukkTvsLuUknva1',
#      'id': '5SXuuuRpukkTvsLuUknva1',
#      'name': 'Baby Keem',
#      'type': 'artist',
#      'uri': 'spotify:artist:5SXuuuRpukkTvsLuUknva1'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3r46DPIQeBQbjvjjV5mXGg'},
#    'href': 'https://api.spotify.com/v1/albums/3r46DPIQeBQbjvjjV5mXGg',
#    'id': '3r46DPIQeBQbjvjjV5mXGg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731bfa23b13d0504fb90c37b39',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021bfa23b13d0504fb90c37b39',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511bfa23b13d0504fb90c37b39',
#      'width': 64}],
#    'name': 'The Melodic Blue',
#    'release_date': '2021-09-10',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:3r46DPIQeBQbjvjjV5mXGg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5SXuuuRpukkTvsLuUknva1'},
#     'href': 'https://api.spotify.com/v1/artists/5SXuuuRpukkTvsLuUknva1',
#     'id': '5SXuuuRpukkTvsLuUknva1',
#     'name': 'Baby Keem',
#     'type': 'artist',
#     'uri': 'spotify:artist:5SXuuuRpukkTvsLuUknva1'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#     'href': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg',
#     'id': '2YZyLoL8N0Wb9xBt1NhZWg',
#     'name': 'Kendrick Lamar',
#     'type': 'artist',
#     'uri': 'spotify:artist:2YZyLoL8N0Wb9xBt1NhZWg'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 252262,
#   'explicit': True,
#   'external_ids': {'isrc': 'USSM12105949'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3QFInJAm9eyaho5vBzxInN'},
#   'href': 'https://api.spotify.com/v1/tracks/3QFInJAm9eyaho5vBzxInN',
#   'id': '3QFInJAm9eyaho5vBzxInN',
#   'is_local': False,
#   'name': 'family ties (with Kendrick Lamar)',
#   'popularity': 84,
#   'preview_url': 'https://p.scdn.co/mp3-preview/376965c332ef1da7f59826c2c12160456e960b8b?cid=8e3b4a50b2ff4b929df3b7105c7850fb',
#   'track_number': 10,
#   'type': 'track',
#   'uri': 'spotify:track:3QFInJAm9eyaho5vBzxInN'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#      'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#      'id': '1uNFoZAHBGtllmzznpCI3s',
#      'name': 'Justin Bieber',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5dGWwsZ9iB2Xc3UKR0gif2'},
#    'href': 'https://api.spotify.com/v1/albums/5dGWwsZ9iB2Xc3UKR0gif2',
#    'id': '5dGWwsZ9iB2Xc3UKR0gif2',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e6f407c7f3a0ec98845e4431',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e6f407c7f3a0ec98845e4431',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e6f407c7f3a0ec98845e4431',
#      'width': 64}],
#    'name': 'Justice',
#    'release_date': '2021-03-19',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:5dGWwsZ9iB2Xc3UKR0gif2'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#     'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#     'id': '1uNFoZAHBGtllmzznpCI3s',
#     'name': 'Justin Bieber',
#     'type': 'artist',
#     'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 153190,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM72102635'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6I3mqTwhRpn34SLVafSH7G'},
#   'href': 'https://api.spotify.com/v1/tracks/6I3mqTwhRpn34SLVafSH7G',
#   'id': '6I3mqTwhRpn34SLVafSH7G',
#   'is_local': False,
#   'name': 'Ghost',
#   'popularity': 87,
#   'preview_url': None,
#   'track_number': 11,
#   'type': 'track',
#   'uri': 'spotify:track:6I3mqTwhRpn34SLVafSH7G'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#    'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#    'id': '0JGOiO34nwfUdDrD612dOp',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#      'width': 64}],
#    'name': 'Happier Than Ever',
#    'release_date': '2021-07-30',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 298899,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUM72105936'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4RVwu0g32PAqgUiJoXsdF8'},
#   'href': 'https://api.spotify.com/v1/tracks/4RVwu0g32PAqgUiJoXsdF8',
#   'id': '4RVwu0g32PAqgUiJoXsdF8',
#   'is_local': False,
#   'name': 'Happier Than Ever',
#   'popularity': 88,
#   'preview_url': None,
#   'track_number': 15,
#   'type': 'track',
#   'uri': 'spotify:track:4RVwu0g32PAqgUiJoXsdF8'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ujvZU2thXjZgFKPUt1rDt'},
#      'href': 'https://api.spotify.com/v1/artists/5ujvZU2thXjZgFKPUt1rDt',
#      'id': '5ujvZU2thXjZgFKPUt1rDt',
#      'name': 'Chayce Beckham',
#      'type': 'artist',
#      'uri': 'spotify:artist:5ujvZU2thXjZgFKPUt1rDt'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2iooIm9txIXCow2rvSg7Aa'},
#    'href': 'https://api.spotify.com/v1/albums/2iooIm9txIXCow2rvSg7Aa',
#    'id': '2iooIm9txIXCow2rvSg7Aa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735de6bc066ec7ab42359bde57',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025de6bc066ec7ab42359bde57',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515de6bc066ec7ab42359bde57',
#      'width': 64}],
#    'name': '23',
#    'release_date': '2021-05-14',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2iooIm9txIXCow2rvSg7Aa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ujvZU2thXjZgFKPUt1rDt'},
#     'href': 'https://api.spotify.com/v1/artists/5ujvZU2thXjZgFKPUt1rDt',
#     'id': '5ujvZU2thXjZgFKPUt1rDt',
#     'name': 'Chayce Beckham',
#     'type': 'artist',
#     'uri': 'spotify:artist:5ujvZU2thXjZgFKPUt1rDt'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 228144,
#   'explicit': False,
#   'external_ids': {'isrc': 'QMRSZ2101045'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2ixkIrn45mNfdLDLHuyfRt'},
#   'href': 'https://api.spotify.com/v1/tracks/2ixkIrn45mNfdLDLHuyfRt',
#   'id': '2ixkIrn45mNfdLDLHuyfRt',
#   'is_local': False,
#   'name': '23',
#   'popularity': 78,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3eecc5c99bdf656565487479a00b51b008da860d?cid=8e3b4a50b2ff4b929df3b7105c7850fb',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2ixkIrn45mNfdLDLHuyfRt'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#      'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#      'id': '1McMsnEElThX1knmY4oliG',
#      'name': 'Olivia Rodrigo',
#      'type': 'artist',
#      'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6s84u2TUpR3wdUv4NgKA2j'},
#    'href': 'https://api.spotify.com/v1/albums/6s84u2TUpR3wdUv4NgKA2j',
#    'id': '6s84u2TUpR3wdUv4NgKA2j',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a91c10fe9472d9bd89802e5a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a91c10fe9472d9bd89802e5a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a91c10fe9472d9bd89802e5a',
#      'width': 64}],
#    'name': 'SOUR',
#    'release_date': '2021-05-21',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:6s84u2TUpR3wdUv4NgKA2j'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#     'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#     'id': '1McMsnEElThX1knmY4oliG',
#     'name': 'Olivia Rodrigo',
#     'type': 'artist',
#     'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 229226,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG12101243'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5CZ40GBx1sQ9agT82CLQCT'},
#   'href': 'https://api.spotify.com/v1/tracks/5CZ40GBx1sQ9agT82CLQCT',
#   'id': '5CZ40GBx1sQ9agT82CLQCT',
#   'is_local': False,
#   'name': 'traitor',
#   'popularity': 88,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:5CZ40GBx1sQ9agT82CLQCT'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gW0r5CkdEUMm42w9XpyZO'},
#      'href': 'https://api.spotify.com/v1/artists/7gW0r5CkdEUMm42w9XpyZO',
#      'id': '7gW0r5CkdEUMm42w9XpyZO',
#      'name': 'Laufey',
#      'type': 'artist',
#      'uri': 'spotify:artist:7gW0r5CkdEUMm42w9XpyZO'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/09KZU0NsS7jRa5p0SflmGY'},
#      'href': 'https://api.spotify.com/v1/artists/09KZU0NsS7jRa5p0SflmGY',
#      'id': '09KZU0NsS7jRa5p0SflmGY',
#      'name': 'Philharmonia Orchestra',
#      'type': 'artist',
#      'uri': 'spotify:artist:09KZU0NsS7jRa5p0SflmGY'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2YkyuQGoMV2FlG7mFprnRf'},
#    'href': 'https://api.spotify.com/v1/albums/2YkyuQGoMV2FlG7mFprnRf',
#    'id': '2YkyuQGoMV2FlG7mFprnRf',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2739457bba66a2daf4456855bb7',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e029457bba66a2daf4456855bb7',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048519457bba66a2daf4456855bb7',
#      'width': 64}],
#    'name': 'Let You Break My Heart Again',
#    'release_date': '2021-08-13',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2YkyuQGoMV2FlG7mFprnRf'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gW0r5CkdEUMm42w9XpyZO'},
#     'href': 'https://api.spotify.com/v1/artists/7gW0r5CkdEUMm42w9XpyZO',
#     'id': '7gW0r5CkdEUMm42w9XpyZO',
#     'name': 'Laufey',
#     'type': 'artist',
#     'uri': 'spotify:artist:7gW0r5CkdEUMm42w9XpyZO'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/09KZU0NsS7jRa5p0SflmGY'},
#     'href': 'https://api.spotify.com/v1/artists/09KZU0NsS7jRa5p0SflmGY',
#     'id': '09KZU0NsS7jRa5p0SflmGY',
#     'name': 'Philharmonia Orchestra',
#     'type': 'artist',
#     'uri': 'spotify:artist:09KZU0NsS7jRa5p0SflmGY'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 269066,
#   'explicit': False,
#   'external_ids': {'isrc': 'TCAFR2175884'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/709p9UGPAuyImWf1Z3vjRo'},
#   'href': 'https://api.spotify.com/v1/tracks/709p9UGPAuyImWf1Z3vjRo',
#   'id': '709p9UGPAuyImWf1Z3vjRo',
#   'is_local': False,
#   'name': 'Let You Break My Heart Again',
#   'popularity': 81,
#   'preview_url': 'https://p.scdn.co/mp3-preview/fe19b8ff802a02e7388fbf596e33132ff923bd4f?cid=8e3b4a50b2ff4b929df3b7105c7850fb',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:709p9UGPAuyImWf1Z3vjRo'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#      'href': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM',
#      'id': '4oUHIQIBe0LHzYfvXNW4QM',
#      'name': 'Morgan Wallen',
#      'type': 'artist',
#      'uri': 'spotify:artist:4oUHIQIBe0LHzYfvXNW4QM'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6JlCkqkqobGirPsaleJpFr'},
#    'href': 'https://api.spotify.com/v1/albums/6JlCkqkqobGirPsaleJpFr',
#    'id': '6JlCkqkqobGirPsaleJpFr',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737d6813fd233f3bc4977cceca',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027d6813fd233f3bc4977cceca',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517d6813fd233f3bc4977cceca',
#      'width': 64}],
#    'name': 'Dangerous: The Double Album',
#    'release_date': '2021-01-08',
#    'release_date_precision': 'day',
#    'total_tracks': 30,
#    'type': 'album',
#    'uri': 'spotify:album:6JlCkqkqobGirPsaleJpFr'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4oUHIQIBe0LHzYfvXNW4QM'},
#     'href': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM',
#     'id': '4oUHIQIBe0LHzYfvXNW4QM',
#     'name': 'Morgan Wallen',
#     'type': 'artist',
#     'uri': 'spotify:artist:4oUHIQIBe0LHzYfvXNW4QM'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 293706,
#   'explicit': False,
#   'external_ids': {'isrc': 'QZ22S1800057'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0mKnuxVkPi5h0kuvZl44VM'},
#   'href': 'https://api.spotify.com/v1/tracks/0mKnuxVkPi5h0kuvZl44VM',
#   'id': '0mKnuxVkPi5h0kuvZl44VM',
#   'is_local': False,
#   'name': 'Cover Me Up',
#   'popularity': 79,
#   'preview_url': None,
#   'track_number': 13,
#   'type': 'track',
#   'uri': 'spotify:track:0mKnuxVkPi5h0kuvZl44VM'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6EPlBSH2RSiettczlz7ihV'},
#      'href': 'https://api.spotify.com/v1/artists/6EPlBSH2RSiettczlz7ihV',
#      'id': '6EPlBSH2RSiettczlz7ihV',
#      'name': 'Sleepy Hallow',
#      'type': 'artist',
#      'uri': 'spotify:artist:6EPlBSH2RSiettczlz7ihV'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/38nZLvJx8A9p4YYpTG5iFP'},
#    'href': 'https://api.spotify.com/v1/albums/38nZLvJx8A9p4YYpTG5iFP',
#    'id': '38nZLvJx8A9p4YYpTG5iFP',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27378376f650afd63698b82e4b1',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0278376f650afd63698b82e4b1',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485178376f650afd63698b82e4b1',
#      'width': 64}],
#    'name': 'Still Sleep?',
#    'release_date': '2021-06-02',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:38nZLvJx8A9p4YYpTG5iFP'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6EPlBSH2RSiettczlz7ihV'},
#     'href': 'https://api.spotify.com/v1/artists/6EPlBSH2RSiettczlz7ihV',
#     'id': '6EPlBSH2RSiettczlz7ihV',
#     'name': 'Sleepy Hallow',
#     'type': 'artist',
#     'uri': 'spotify:artist:6EPlBSH2RSiettczlz7ihV'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 123986,
#   'explicit': True,
#   'external_ids': {'isrc': 'USRC12100442'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4XvcHTUfIlWfyJTRG0aqlo'},
#   'href': 'https://api.spotify.com/v1/tracks/4XvcHTUfIlWfyJTRG0aqlo',
#   'id': '4XvcHTUfIlWfyJTRG0aqlo',
#   'is_local': False,
#   'name': '2055',
#   'popularity': 83,
#   'preview_url': 'https://p.scdn.co/mp3-preview/d05766a84b267bc5518625b595b8c9f333b46e31?cid=8e3b4a50b2ff4b929df3b7105c7850fb',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:4XvcHTUfIlWfyJTRG0aqlo'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7htQnykNfk2Bu39bSw7owz'},
#      'href': 'https://api.spotify.com/v1/artists/7htQnykNfk2Bu39bSw7owz',
#      'id': '7htQnykNfk2Bu39bSw7owz',
#      'name': 'ame',
#      'type': 'artist',
#      'uri': 'spotify:artist:7htQnykNfk2Bu39bSw7owz'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2Iyw159svPU1i8iNnHDIne'},
#    'href': 'https://api.spotify.com/v1/albums/2Iyw159svPU1i8iNnHDIne',
#    'id': '2Iyw159svPU1i8iNnHDIne',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27302ef99f460f639b15f2575c5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0202ef99f460f639b15f2575c5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485102ef99f460f639b15f2575c5',
#      'width': 64}],
#    'name': 'grey cloud',
#    'release_date': '2021-08-13',
#    'release_date_precision': 'day',
#    'total_tracks': 3,
#    'type': 'album',
#    'uri': 'spotify:album:2Iyw159svPU1i8iNnHDIne'},
# ...
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5hxKw2PurC0i1VVJMAntDU'},
#    'href': 'https://api.spotify.com/v1/albums/5hxKw2PurC0i1VVJMAntDU',
#    'id': '5hxKw2PurC0i1VVJMAntDU',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273eb10050f6fe8e2783a91a4b1',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02eb10050f6fe8e2783a91a4b1',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851eb10050f6fe8e2783a91a4b1',
#      'width': 64}],
#    'name': "Wildest Dreams (Taylor's Version)",
#    'release_date': '2021-09-17',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:5hxKw2PurC0i1VVJMAntDU'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 220433,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG12103658'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1Ov37jtRQ2YNAe8HzfczkL'},
#   'href': 'https://api.spotify.com/v1/tracks/1Ov37jtRQ2YNAe8HzfczkL',
#   'id': '1Ov37jtRQ2YNAe8HzfczkL',
#   'is_local': False,
#   'name': "Wildest Dreams (Taylor's Version)",
#   'popularity': 87,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:1Ov37jtRQ2YNAe8HzfczkL'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#      'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#      'id': '64KEffDW9EtZ1y2vBYgq8T',
#      'name': 'Marshmello',
#      'type': 'artist',
#      'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#      'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#      'id': '7gOdHgIoIKoe4i9Tta6qdD',
#      'name': 'Jonas Brothers',
#      'type': 'artist',
#      'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/66JuK41D3LpkbX3HCTGcQk'},
#    'href': 'https://api.spotify.com/v1/albums/66JuK41D3LpkbX3HCTGcQk',
#    'id': '66JuK41D3LpkbX3HCTGcQk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ae40468931087f78919b86ce',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ae40468931087f78919b86ce',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ae40468931087f78919b86ce',
#      'width': 64}],
#    'name': 'Leave Before You Love Me',
#    'release_date': '2021-05-21',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:66JuK41D3LpkbX3HCTGcQk'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#     'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#     'id': '64KEffDW9EtZ1y2vBYgq8T',
#     'name': 'Marshmello',
#     'type': 'artist',
#     'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7gOdHgIoIKoe4i9Tta6qdD'},
#     'href': 'https://api.spotify.com/v1/artists/7gOdHgIoIKoe4i9Tta6qdD',
#     'id': '7gOdHgIoIKoe4i9Tta6qdD',
#     'name': 'Jonas Brothers',
#     'type': 'artist',
#     'uri': 'spotify:artist:7gOdHgIoIKoe4i9Tta6qdD'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 154983,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG12102313'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4qu63nuBpdn0qHUHuObEj1'},
#   'href': 'https://api.spotify.com/v1/tracks/4qu63nuBpdn0qHUHuObEj1',
#   'id': '4qu63nuBpdn0qHUHuObEj1',
#   'is_local': False,
#   'name': 'Leave Before You Love Me (with Jonas Brothers)',
#   'popularity': 84,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:4qu63nuBpdn0qHUHuObEj1'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19k8AgwwTSxeaxkOuCQEJs'},
#      'href': 'https://api.spotify.com/v1/artists/19k8AgwwTSxeaxkOuCQEJs',
#      'id': '19k8AgwwTSxeaxkOuCQEJs',
#      'name': 'Jelly Roll',
#      'type': 'artist',
#      'uri': 'spotify:artist:19k8AgwwTSxeaxkOuCQEJs'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4aWPCLZWr9gG0ucLIMJavx'},
#    'href': 'https://api.spotify.com/v1/albums/4aWPCLZWr9gG0ucLIMJavx',
#    'id': '4aWPCLZWr9gG0ucLIMJavx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ff60ab1f9e58d3139a06fed8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ff60ab1f9e58d3139a06fed8',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ff60ab1f9e58d3139a06fed8',
#      'width': 64}],
#    'name': 'Ballads Of The Broken',
#    'release_date': '2021-09-17',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:4aWPCLZWr9gG0ucLIMJavx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19k8AgwwTSxeaxkOuCQEJs'},
#     'href': 'https://api.spotify.com/v1/artists/19k8AgwwTSxeaxkOuCQEJs',
#     'id': '19k8AgwwTSxeaxkOuCQEJs',
#     'name': 'Jelly Roll',
#     'type': 'artist',
#     'uri': 'spotify:artist:19k8AgwwTSxeaxkOuCQEJs'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 232093,
#   'explicit': True,
#   'external_ids': {'isrc': 'QMRSZ2102218'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/25VQoiuyc0HkC5FQTj1a8G'},
#   'href': 'https://api.spotify.com/v1/tracks/25VQoiuyc0HkC5FQTj1a8G',
#   'id': '25VQoiuyc0HkC5FQTj1a8G',
#   'is_local': False,
#   'name': 'Son Of A Sinner',
#   'popularity': 80,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0453b38bfe76fbd1cdc67ca63154fc024c875247?cid=8e3b4a50b2ff4b929df3b7105c7850fb',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:25VQoiuyc0HkC5FQTj1a8G'}]

# %%
# track_id
t[0]["id"]
# Out:
# '3QFInJAm9eyaho5vBzxInN'

# %%
# track_name
t[0]["name"]
# Out:
# 'family ties (with Kendrick Lamar)'

# %%
# track_popularity
t[0]["popularity"]
# Out:
# 84

# %%
# artist_name
t[0]["artists"][0]["name"]
# Out:
# 'Baby Keem'

# %%
# function to get track info from the search
def get_tracks(to_search):
    track_id = []
    track_name = []
    track_popularity = []
    artist_id = []
    artist_name = []
    
    for i in (range(0,1000,50)):
        search = sp.search(q= to_search, type="track", limit=50, offset = i)
        for i, t in enumerate(search['tracks']['items']):
            track_id.append(t["id"])
            track_name.append(t["name"])
            track_popularity.append(t["popularity"])
            artist_name.append(t["artists"][0]['name'])
            artist_id.append(t["artists"][0]['id'])

    
    dict = {"track_id": track_id, "track_name": track_name, "track_popularity": track_popularity, "artist_id": artist_id, "artist_name": artist_name}
            
    return dict

# %% [markdown]
# **We will get add songs from 2020 to 2023 to the full song list from kaggle.**

# %%
latest_songs = pd.DataFrame()
for i in list(["year 2020", "year 2021", "year 2022", "year 2023"]):
    y = get_tracks(i)
    new_df = pd.DataFrame.from_dict(y)
    latest_songs = pd.concat([latest_songs, new_df])

# %%
latest_songs.head()
# Out:
#                  track_id                                         track_name
# 0  4pUphnieXvbcoc6sM8XiPN  Wizards And Warriors/Ironsword (Title - Forest...  \
# 1  03VrhBjoCp0rSjajdhNE5N                                          Year 2020
# 2  0t2q2c43AATY4z1GI883Be                                        Summer 2020
# 3  0MlkZnfwsjwHHSfn07N8ao                                Longest Year (2020)
# 4  6EpPQjzITlNYDAhX4q6w2e                                   Bad Dudes (lv 2)
#
#    track_popularity               artist_id    artist_name
# 0                18  6JMGrupbzJZ3yuQhTGyeHr      Year 200X
# 1                 1  46102Rmv7OVlBvNRnH3fj2  Iñigo Vontier
# 2                55  5ZS223C6JyBfXasXxrRqOk     Jhené Aiko
# 3                17  0VOR7Ie9xUSb45fzIIVJQ1        Hammock
# 4                20  6JMGrupbzJZ3yuQhTGyeHr      Year 200X

# %%
latest_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          4000 non-null   object
#  1   track_name        4000 non-null   object
#  2   track_popularity  4000 non-null   int64
#  3   artist_id         4000 non-null   object
#  4   artist_name       4000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 187.5+ KB

# %%
latest_songs.duplicated().sum()
# Out:
# 1037

# %%
latest = latest_songs.drop_duplicates()

# %%
latest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2963 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          2963 non-null   object
#  1   track_name        2963 non-null   object
#  2   track_popularity  2963 non-null   int64
#  3   artist_id         2963 non-null   object
#  4   artist_name       2963 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 138.9+ KB

# %% [markdown]
# ### GET AUDIO FEATURES OF LATEST SONGS

# %%
def audio_features(track_ids_list):
    audio_features = pd.DataFrame()
    for i, o in zip(range(0, (len(track_ids_list)+100), 100), range(100, (len(track_ids_list)+100), 100)):
        try:
            features = sp.audio_features(track_ids_list[i:o])
            features_df = pd.DataFrame(features)
            audio_features = pd.concat([audio_features, features_df])
        except AttributeError:
            pass
    return audio_features

# %%
audio_feat = audio_features(latest.track_id)

# %%
audio_feat
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness
# 0         0.4020   0.927    2    -5.898     0       0.0440      0.000033  \
# 1         0.1720   0.445    0   -16.124     1       0.0492      0.935000
# 2         0.4010   0.485    6   -10.787     0       0.2160      0.831000
# 3         0.0705   0.286    2   -14.865     1       0.0444      0.685000
# 4         0.3360   0.828    7    -8.832     1       0.0447      0.000008
# ..           ...     ...  ...       ...   ...          ...           ...
# 58        0.5960   0.655    7    -9.729     0       0.0621      0.009350
# 59        0.5610   0.634    9   -11.572     1       0.0596      0.000442
# 60        0.4230   0.407   10    -7.450     1       0.0267      0.312000
# 61        0.6750   0.876    7    -6.408     1       0.0403      0.047400
# 62        0.6020   0.232    1   -15.624     1       0.0304      0.772000
#
#     instrumentalness  liveness  valence    tempo            type
# 0           0.937000    0.2070   0.4540   99.900  audio_features  \
# 1           0.102000    0.6330   0.0352  112.356  audio_features
# 2           0.000292    0.0907   0.5400  169.949  audio_features
# 3           0.675000    0.1870   0.0313   78.251  audio_features
# 4           0.934000    0.1860   0.5900  139.649  audio_features
# ..               ...       ...      ...      ...             ...
# 58          0.000000    0.0811   0.7010  119.938  audio_features
# 59          0.017800    0.1230   0.4260  130.065  audio_features
# 60          0.000961    0.1100   0.1610  139.048  audio_features
# 61          0.000000    0.3000   0.9100  125.666  audio_features
# 62          0.000000    0.7630   0.3130   77.247  audio_features
#
#                         id                                   uri
# 0   4pUphnieXvbcoc6sM8XiPN  spotify:track:4pUphnieXvbcoc6sM8XiPN  \
# 1   03VrhBjoCp0rSjajdhNE5N  spotify:track:03VrhBjoCp0rSjajdhNE5N
# 2   0t2q2c43AATY4z1GI883Be  spotify:track:0t2q2c43AATY4z1GI883Be
# 3   0MlkZnfwsjwHHSfn07N8ao  spotify:track:0MlkZnfwsjwHHSfn07N8ao
# 4   6EpPQjzITlNYDAhX4q6w2e  spotify:track:6EpPQjzITlNYDAhX4q6w2e
# ..                     ...                                   ...
# 58  4LVadKqUEEjfyXuukTvZ1o  spotify:track:4LVadKqUEEjfyXuukTvZ1o
# 59  0oujrnqy3aYS0aJhjk3SJ9  spotify:track:0oujrnqy3aYS0aJhjk3SJ9
# 60  17fExFDNOPrEw02olB2v6h  spotify:track:17fExFDNOPrEw02olB2v6h
# 61  0cwYe963tsdUtd5gqHiaDN  spotify:track:0cwYe963tsdUtd5gqHiaDN
# 62  5EA4KGI5TcHo3Sy0HcFXnK  spotify:track:5EA4KGI5TcHo3Sy0HcFXnK
#
#                                            track_href
# 0   https://api.spotify.com/v1/tracks/4pUphnieXvbc...  \
# 1   https://api.spotify.com/v1/tracks/03VrhBjoCp0r...
# 2   https://api.spotify.com/v1/tracks/0t2q2c43AATY...
# 3   https://api.spotify.com/v1/tracks/0MlkZnfwsjwH...
# 4   https://api.spotify.com/v1/tracks/6EpPQjzITlNY...
# ..                                                ...
# 58  https://api.spotify.com/v1/tracks/4LVadKqUEEjf...
# 59  https://api.spotify.com/v1/tracks/0oujrnqy3aYS...
# 60  https://api.spotify.com/v1/tracks/17fExFDNOPrE...
# 61  https://api.spotify.com/v1/tracks/0cwYe963tsdU...
# 62  https://api.spotify.com/v1/tracks/5EA4KGI5TcHo...
#
#                                          analysis_url  duration_ms
# 0   https://api.spotify.com/v1/audio-analysis/4pUp...       281845  \
# 1   https://api.spotify.com/v1/audio-analysis/03Vr...       329143
# 2   https://api.spotify.com/v1/audio-analysis/0t2q...       196000
# 3   https://api.spotify.com/v1/audio-analysis/0Mlk...       533707
# 4   https://api.spotify.com/v1/audio-analysis/6EpP...       105440
# ..                                                ...          ...
# 58  https://api.spotify.com/v1/audio-analysis/4LVa...       232229
# 59  https://api.spotify.com/v1/audio-analysis/0ouj...       204513
# 60  https://api.spotify.com/v1/audio-analysis/17fE...       285120
# 61  https://api.spotify.com/v1/audio-analysis/0cwY...       171434
# 62  https://api.spotify.com/v1/audio-analysis/5EA4...       153240
#
#     time_signature
# 0                4
# 1                3
# 2                4
# 3                4
# 4                4
# ..             ...
# 58               4
# 59               4
# 60               3
# 61               4
# 62               4
#
# [2763 rows x 18 columns]

# %%
cols_to_drop = ['type', 'uri', 'analysis_url', 'time_signature']
audio_features = audio_feat.drop(columns=cols_to_drop)

# %%
audio_features.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness
# 0        0.4020   0.927    2    -5.898     0       0.0440      0.000033  \
# 1        0.1720   0.445    0   -16.124     1       0.0492      0.935000
# 2        0.4010   0.485    6   -10.787     0       0.2160      0.831000
# 3        0.0705   0.286    2   -14.865     1       0.0444      0.685000
# 4        0.3360   0.828    7    -8.832     1       0.0447      0.000008
#
#    instrumentalness  liveness  valence    tempo                      id
# 0          0.937000    0.2070   0.4540   99.900  4pUphnieXvbcoc6sM8XiPN  \
# 1          0.102000    0.6330   0.0352  112.356  03VrhBjoCp0rSjajdhNE5N
# 2          0.000292    0.0907   0.5400  169.949  0t2q2c43AATY4z1GI883Be
# 3          0.675000    0.1870   0.0313   78.251  0MlkZnfwsjwHHSfn07N8ao
# 4          0.934000    0.1860   0.5900  139.649  6EpPQjzITlNYDAhX4q6w2e
#
#                                           track_href  duration_ms
# 0  https://api.spotify.com/v1/tracks/4pUphnieXvbc...       281845
# 1  https://api.spotify.com/v1/tracks/03VrhBjoCp0r...       329143
# 2  https://api.spotify.com/v1/tracks/0t2q2c43AATY...       196000
# 3  https://api.spotify.com/v1/tracks/0MlkZnfwsjwH...       533707
# 4  https://api.spotify.com/v1/tracks/6EpPQjzITlNY...       105440

# %%
# merge audio features with track infos
full_latest = latest.merge(audio_features, left_on = "track_id", right_on = "id")

# %%
# save to csv for safeguarding
#full_latest.to_csv('songs_2020-3.csv', index=False)

# %%
# drop some redundant columns
connect = full_latest.drop(columns=["id", "artist_id"])

# %%
connect
# Out:
#                     track_id
# 0     4pUphnieXvbcoc6sM8XiPN  \
# 1     03VrhBjoCp0rSjajdhNE5N
# 2     0t2q2c43AATY4z1GI883Be
# 3     0MlkZnfwsjwHHSfn07N8ao
# 4     6EpPQjzITlNYDAhX4q6w2e
# ...                      ...
# 2758  4LVadKqUEEjfyXuukTvZ1o
# 2759  0oujrnqy3aYS0aJhjk3SJ9
# 2760  17fExFDNOPrEw02olB2v6h
# 2761  0cwYe963tsdUtd5gqHiaDN
# 2762  5EA4KGI5TcHo3Sy0HcFXnK
#
#                                              track_name  track_popularity
# 0     Wizards And Warriors/Ironsword (Title - Forest...                18  \
# 1                                             Year 2020                 1
# 2                                           Summer 2020                55
# 3                                   Longest Year (2020)                17
# 4                                      Bad Dudes (lv 2)                20
# ...                                                 ...               ...
# 2758                   Just Getting Started - 2023 Edit                 0
# 2759                             Let It Out - 2023 Edit                 0
# 2760                                   A Thousand Years                 4
# 2761            Body To Body (ZYX Edit Remastered 2023)                 5
# 2762                                       Wasted Years                 4
#
#           artist_name  danceability  energy  key  loudness  mode  speechiness
# 0           Year 200X        0.4020   0.927    2    -5.898     0       0.0440  \
# 1       Iñigo Vontier        0.1720   0.445    0   -16.124     1       0.0492
# 2          Jhené Aiko        0.4010   0.485    6   -10.787     0       0.2160
# 3             Hammock        0.0705   0.286    2   -14.865     1       0.0444
# 4           Year 200X        0.3360   0.828    7    -8.832     1       0.0447
# ...               ...           ...     ...  ...       ...   ...          ...
# 2758        Andy Joel        0.5960   0.655    7    -9.729     0       0.0621
# 2759        Andy Joel        0.5610   0.634    9   -11.572     1       0.0596
# 2760  Christina Perri        0.4230   0.407   10    -7.450     1       0.0267
# 2761        Radiorama        0.6750   0.876    7    -6.408     1       0.0403
# 2762          Daniela        0.6020   0.232    1   -15.624     1       0.0304
#
#       acousticness  instrumentalness  liveness  valence    tempo
# 0         0.000033          0.937000    0.2070   0.4540   99.900  \
# 1         0.935000          0.102000    0.6330   0.0352  112.356
# 2         0.831000          0.000292    0.0907   0.5400  169.949
# 3         0.685000          0.675000    0.1870   0.0313   78.251
# 4         0.000008          0.934000    0.1860   0.5900  139.649
# ...            ...               ...       ...      ...      ...
# 2758      0.009350          0.000000    0.0811   0.7010  119.938
# 2759      0.000442          0.017800    0.1230   0.4260  130.065
# 2760      0.312000          0.000961    0.1100   0.1610  139.048
# 2761      0.047400          0.000000    0.3000   0.9100  125.666
# 2762      0.772000          0.000000    0.7630   0.3130   77.247
#
#                                              track_href  duration_ms
# 0     https://api.spotify.com/v1/tracks/4pUphnieXvbc...       281845
# 1     https://api.spotify.com/v1/tracks/03VrhBjoCp0r...       329143
# 2     https://api.spotify.com/v1/tracks/0t2q2c43AATY...       196000
# 3     https://api.spotify.com/v1/tracks/0MlkZnfwsjwH...       533707
# 4     https://api.spotify.com/v1/tracks/6EpPQjzITlNY...       105440
# ...                                                 ...          ...
# 2758  https://api.spotify.com/v1/tracks/4LVadKqUEEjf...       232229
# 2759  https://api.spotify.com/v1/tracks/0oujrnqy3aYS...       204513
# 2760  https://api.spotify.com/v1/tracks/17fExFDNOPrE...       285120
# 2761  https://api.spotify.com/v1/tracks/0cwYe963tsdU...       171434
# 2762  https://api.spotify.com/v1/tracks/5EA4KGI5TcHo...       153240
#
# [2763 rows x 17 columns]

# %%
connect.shape # this dataframe has more columns so we will definitely drop some more to have the same attributes as the 160k songs
# Out:
# (2763, 17)

# %%
connect.columns
# Out:
# Index(['track_id', 'track_name', 'track_popularity', 'artist_name',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'track_href', 'duration_ms'],
#       dtype='object')

# %%
concat = connect.drop(["track_href", "track_popularity"], axis=1)
concat.shape # now we have the same number of columns. we can proceed to concatenating the dataframes
# Out:
# (2763, 15)

# %%
list_cols = list(concat.columns) # columns to keep. we will use these to make sure we have the same columns from the df160k dataset
list_cols
# Out:
# ['track_id',
#  'track_name',
#  'artist_name',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms']

# %% [markdown]
# ### KAGGLE 160K DATASET

# %%
df_160k = pd.read_csv('160k_data.csv') # list of songs from kaggle from 1921 to june 2020
df_160k
# Out:
#                             id
# 0       0gNNToCW3qjabgTyBSjt3H  \
# 1       0tMgFpOrXZR6irEOLNWwJL
# 2       2ZywW3VyVx6rrlrX75n3JB
# 3       6DdWA7D1o5TU2kXWyCLcch
# 4       3vMmwsAiLDCfyc1jl76lQE
# ...                        ...
# 169902  4KiYPYpm4ultIp247ftPlI
# 169903  42tFTth2jcF7iSo0RBjfJF
# 169904  6XP9L7di5JnOc9WaeAW8oe
# 169905  3Gpdzw72aBVJSrm5J1leVK
# 169906  2p5DfmIUTLH79elmaSCCR5
#
#                                                      name
# 0                               !Que Vida! - Mono Version  \
# 1                                                    "40"
# 2                                             "40" - Live
# 3                                  "40" - Remastered 2008
# 4                                  "40" - Remastered 2008
# ...                                                   ...
# 169902                                 텅 빈 마음 Empty Heart
# 169903                                     피카부 Peek-A-Boo
# 169904                                     행복 (Happiness)
# 169905  헤어지지 못하는 여자, 떠나가지 못하는 남자 Can't Breakup Girl, C...
# 169906                화려하지 않은 고백 Confession Is Not Flashy
#
#                         artists  duration_ms release_date  year  acousticness
# 0                      ['Love']       220560      11/1/66  1966        0.5250  \
# 1                        ['U2']       157840      2/28/83  1983        0.2280
# 2                        ['U2']       226200      8/20/83  1983        0.0998
# 3                        ['U2']       157667      2/28/83  1983        0.1850
# 4                        ['U2']       157667      2/28/83  1983        0.1850
# ...                         ...          ...          ...   ...           ...
# 169902       ['LEE SEUNG HWAN']       249893     10/15/89  1989        0.4290
# 169903           ['Red Velvet']       189050     11/17/17  2017        0.0868
# 169904           ['Red Velvet']       220987       8/1/14  2014        0.3230
# 169905  ['Leessang', 'Jung In']       284627      10/6/09  2009        0.1500
# 169906       ['LEE SEUNG HWAN']       230733       9/1/93  1993        0.4480
#
#         danceability  energy  instrumentalness  liveness  loudness
# 0              0.600   0.540          0.003050    0.1000   -11.803  \
# 1              0.368   0.480          0.707000    0.1590   -11.605
# 2              0.272   0.684          0.014500    0.9460    -9.728
# 3              0.371   0.545          0.582000    0.1830    -9.315
# 4              0.371   0.545          0.582000    0.1830    -9.315
# ...              ...     ...               ...       ...       ...
# 169902         0.547   0.304          0.000000    0.1430   -14.326
# 169903         0.839   0.902          0.002570    0.2720    -3.612
# 169904         0.727   0.871          0.000006    0.7250    -3.099
# 169905         0.523   0.841          0.000000    0.1640    -2.505
# 169906         0.741   0.380          0.000811    0.0806    -9.539
#
#         speechiness    tempo  valence  mode  key  popularity  explicit
# 0            0.0328  125.898    0.547     1    9          26         0
# 1            0.0306  150.166    0.338     1    8          21         0
# 2            0.0505  143.079    0.279     1    8          41         0
# 3            0.0307  150.316    0.310     1    8          37         0
# 4            0.0307  150.316    0.310     1    8          35         0
# ...             ...      ...      ...   ...  ...         ...       ...
# 169902       0.0336   74.164    0.157     0   11          35         0
# 169903       0.0536  114.953    0.639     0    1          69         0
# 169904       0.1580  121.438    0.681     0   10          58         0
# 169905       0.3310  173.903    0.383     0   10          52         0
# 169906       0.0285  101.971    0.264     1    2          43         0
#
# [169907 rows x 19 columns]

# %%
# check columns
df_160k.columns
# Out:
# Index(['id', 'name', 'artists', 'duration_ms', 'release_date', 'year',
#        'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'mode',
#        'key', 'popularity', 'explicit'],
#       dtype='object')

# %%
# rename columns to have the same as the latest songs dataset
df_160k.columns = ['track_id', 'track_name', 'artist_name', 'duration_ms', 'release_date', 'year',
       'acousticness', 'danceability', 'energy', 'instrumentalness',
       'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'mode',
       'key', 'track_popularity', 'explicit']

# %%
# new df with the same columns as the concat df
spotify_160k = df_160k[list_cols]
spotify_160k.head()
# Out:
#                  track_id                 track_name artist_name
# 0  0gNNToCW3qjabgTyBSjt3H  !Que Vida! - Mono Version    ['Love']  \
# 1  0tMgFpOrXZR6irEOLNWwJL                       "40"      ['U2']
# 2  2ZywW3VyVx6rrlrX75n3JB                "40" - Live      ['U2']
# 3  6DdWA7D1o5TU2kXWyCLcch     "40" - Remastered 2008      ['U2']
# 4  3vMmwsAiLDCfyc1jl76lQE     "40" - Remastered 2008      ['U2']
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness
# 0         0.600   0.540    9   -11.803     1       0.0328        0.5250  \
# 1         0.368   0.480    8   -11.605     1       0.0306        0.2280
# 2         0.272   0.684    8    -9.728     1       0.0505        0.0998
# 3         0.371   0.545    8    -9.315     1       0.0307        0.1850
# 4         0.371   0.545    8    -9.315     1       0.0307        0.1850
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0           0.00305     0.100    0.547  125.898       220560
# 1           0.70700     0.159    0.338  150.166       157840
# 2           0.01450     0.946    0.279  143.079       226200
# 3           0.58200     0.183    0.310  150.316       157667
# 4           0.58200     0.183    0.310  150.316       157667

# %% [markdown]
# ### PLAYLIST TRACKS FROM PREVIOUS LAB

# %%
playlist_tracks = pd.read_csv('full_df_playlists.csv')
playlist_tracks.drop(['artist_id', 'id', 'time_signature'], axis=1, inplace=True)

# %%
playlist_tracks.head()
# Out:
#                  track_id                    track                    artist
# 0  5ghIJDpPoe3CfHMGu71E6T  Smells Like Teen Spirit                   Nirvana  \
# 1  1FkoVC85Ds3mFoK0fVqEqP              Self Esteem             The Offspring
# 2  59WN2psjkt1tyaxjspN8fp      Killing In The Name  Rage Against The Machine
# 3  6L89mwZXSOwYl76YXfX13s              Basket Case                 Green Day
# 4  3d9DChrdc6BOeFsbrZ3Is0         Under the Bridge     Red Hot Chili Peppers
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness
# 0         0.502   0.912    1    -4.556     1       0.0564      0.000025  \
# 1         0.488   0.862    0    -7.595     1       0.0476      0.020400
# 2         0.466   0.833    7    -4.215     1       0.3040      0.026600
# 3         0.442   0.943    3    -3.205     1       0.0602      0.002930
# 4         0.559   0.345    4   -13.496     1       0.0459      0.057600
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000173    0.1060    0.720  116.761       301920
# 1          0.000000    0.3590    0.706  104.560       257827
# 2          0.000000    0.0327    0.661   88.785       313573
# 3          0.000009    0.0910    0.781   85.064       181533
# 4          0.000105    0.1410    0.458   84.581       264307

# %%
playlist_tracks.columns = ['track_id', 'track_name', 'artist_name', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'duration_ms']

# %%
# putting all the tracks together
tracks_features = pd.concat([spotify_160k, concat, playlist_tracks])
tracks_features # we now have over 174K tracks. we need to check for any duplicates and null values
# Out:
#                     track_id                     track_name     artist_name
# 0     0gNNToCW3qjabgTyBSjt3H      !Que Vida! - Mono Version        ['Love']  \
# 1     0tMgFpOrXZR6irEOLNWwJL                           "40"          ['U2']
# 2     2ZywW3VyVx6rrlrX75n3JB                    "40" - Live          ['U2']
# 3     6DdWA7D1o5TU2kXWyCLcch         "40" - Remastered 2008          ['U2']
# 4     3vMmwsAiLDCfyc1jl76lQE         "40" - Remastered 2008          ['U2']
# ...                      ...                            ...             ...
# 1698  3d0VZU6Mf2hdZRHA4zry8S                     John Wayne       Lady Gaga
# 1699  4de1X6v99U7tfOXrNUCTbi                          Candy        Doja Cat
# 1700  1GVF9369j7InydwGztCDIZ                Good In Goodbye    Madison Beer
# 1701  6qNB2ChCVPepl5ZjVJJTUW  STUPID (feat. Yung Baby Tate)        Ashnikko
# 1702  1YrgbwVse66pH7ysXLlgO8               Heartbreak Hotel  Abigail Barlow
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness
# 0            0.600   0.540    9   -11.803     1       0.0328       0.52500  \
# 1            0.368   0.480    8   -11.605     1       0.0306       0.22800
# 2            0.272   0.684    8    -9.728     1       0.0505       0.09980
# 3            0.371   0.545    8    -9.315     1       0.0307       0.18500
# 4            0.371   0.545    8    -9.315     1       0.0307       0.18500
# ...            ...     ...  ...       ...   ...          ...           ...
# 1698         0.610   0.667   11    -5.825     0       0.0314       0.00131
# 1699         0.689   0.516    8    -5.857     1       0.0444       0.51300
# 1700         0.658   0.698   11    -5.950     0       0.1770       0.43300
# 1701         0.772   0.637    2    -6.881     1       0.1140       0.00459
# 1702         0.639   0.837    1    -5.445     1       0.0849       0.13900
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.003050    0.1000    0.547  125.898       220560
# 1             0.707000    0.1590    0.338  150.166       157840
# 2             0.014500    0.9460    0.279  143.079       226200
# 3             0.582000    0.1830    0.310  150.316       157667
# 4             0.582000    0.1830    0.310  150.316       157667
# ...                ...       ...      ...      ...          ...
# 1698          0.000180    0.3400    0.510   96.954       174307
# 1699          0.000000    0.1680    0.209  124.876       190907
# 1700          0.000000    0.1740    0.456  139.054       141949
# 1701          0.000000    0.0778    0.540  149.906       167317
# 1702          0.000001    0.3010    0.621  167.161       196325
#
# [174373 rows x 15 columns]

# %%
# clean artist_name column by removing special characters
tracks_features.artist_name = tracks_features.artist_name.apply(lambda x: x.translate({ord(i): None for i in """['"]"""}))

# %%
tracks_features
# Out:
#                     track_id                     track_name     artist_name
# 0     0gNNToCW3qjabgTyBSjt3H      !Que Vida! - Mono Version            Love  \
# 1     0tMgFpOrXZR6irEOLNWwJL                           "40"              U2
# 2     2ZywW3VyVx6rrlrX75n3JB                    "40" - Live              U2
# 3     6DdWA7D1o5TU2kXWyCLcch         "40" - Remastered 2008              U2
# 4     3vMmwsAiLDCfyc1jl76lQE         "40" - Remastered 2008              U2
# ...                      ...                            ...             ...
# 1698  3d0VZU6Mf2hdZRHA4zry8S                     John Wayne       Lady Gaga
# 1699  4de1X6v99U7tfOXrNUCTbi                          Candy        Doja Cat
# 1700  1GVF9369j7InydwGztCDIZ                Good In Goodbye    Madison Beer
# 1701  6qNB2ChCVPepl5ZjVJJTUW  STUPID (feat. Yung Baby Tate)        Ashnikko
# 1702  1YrgbwVse66pH7ysXLlgO8               Heartbreak Hotel  Abigail Barlow
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness
# 0            0.600   0.540    9   -11.803     1       0.0328       0.52500  \
# 1            0.368   0.480    8   -11.605     1       0.0306       0.22800
# 2            0.272   0.684    8    -9.728     1       0.0505       0.09980
# 3            0.371   0.545    8    -9.315     1       0.0307       0.18500
# 4            0.371   0.545    8    -9.315     1       0.0307       0.18500
# ...            ...     ...  ...       ...   ...          ...           ...
# 1698         0.610   0.667   11    -5.825     0       0.0314       0.00131
# 1699         0.689   0.516    8    -5.857     1       0.0444       0.51300
# 1700         0.658   0.698   11    -5.950     0       0.1770       0.43300
# 1701         0.772   0.637    2    -6.881     1       0.1140       0.00459
# 1702         0.639   0.837    1    -5.445     1       0.0849       0.13900
#
#       instrumentalness  liveness  valence    tempo  duration_ms
# 0             0.003050    0.1000    0.547  125.898       220560
# 1             0.707000    0.1590    0.338  150.166       157840
# 2             0.014500    0.9460    0.279  143.079       226200
# 3             0.582000    0.1830    0.310  150.316       157667
# 4             0.582000    0.1830    0.310  150.316       157667
# ...                ...       ...      ...      ...          ...
# 1698          0.000180    0.3400    0.510   96.954       174307
# 1699          0.000000    0.1680    0.209  124.876       190907
# 1700          0.000000    0.1740    0.456  139.054       141949
# 1701          0.000000    0.0778    0.540  149.906       167317
# 1702          0.000001    0.3010    0.621  167.161       196325
#
# [174373 rows x 15 columns]

# %%
# check missing values
tracks_features.isna().sum() # there are none. YAY!
# Out:
# track_id            0
# track_name          0
# artist_name         0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# dtype: int64

# %%
# checking for duplicates
tracks_features.duplicated().sum() # some duplicates were found.
# Out:
# 348

# %%
# remove duplicates
tracks_features = tracks_features.drop_duplicates()
tracks_features.shape
# Out:
# (174025, 15)

# %%
tracks_features[tracks_features.track_name == "Smells Like Teen Spirit"] # a problem encountered: I can definitely see duplicates but they have different track_ids!
# Out:
#                       track_id               track_name artist_name
# 124213  2Wtm3yc0paBifvBSjOhO3b  Smells Like Teen Spirit     Nirvana  \
# 124214  6y1etHPLRsgA467gLBOgBm  Smells Like Teen Spirit     Nirvana
# 124215  5ghIJDpPoe3CfHMGu71E6T  Smells Like Teen Spirit     Nirvana
# 124216  56Cub3qT0VhFQd2Wiblv2w  Smells Like Teen Spirit     Nirvana
# 124217  75aLTVBSGIquqzQ6AkmK3Q  Smells Like Teen Spirit     Nirvana
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness
# 124213         0.502   0.912    1    -4.556     1       0.0564      0.000025  \
# 124214         0.479   0.873    1    -5.896     1       0.0438      0.000014
# 124215         0.502   0.912    1    -4.556     1       0.0564      0.000025
# 124216         0.502   0.912    1    -4.556     1       0.0564      0.000025
# 124217         0.502   0.912    1    -4.556     1       0.0564      0.000025
#
#         instrumentalness  liveness  valence    tempo  duration_ms
# 124213          0.000173    0.1060    0.720  116.761       301920
# 124214          0.000565    0.0974    0.816  116.710       301453
# 124215          0.000173    0.1060    0.720  116.761       301920
# 124216          0.000173    0.1060    0.720  116.761       301920
# 124217          0.000173    0.1060    0.720  116.761       301920

# %% [markdown]
# **Not sure if I'll have time to re-check which track_id is the correct one so this will be left alone for now.**

# %%
# saving the full tracks list to csv for safeguarding and the next step of the song recommendation project
#tracks_features.to_csv('final_full_list2.csv', index=False)
