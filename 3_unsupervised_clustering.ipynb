# %% [markdown]
# # UNSUPERVISED LEARNING: K-MEANS CLUSTERING

# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

from sklearn.metrics import silhouette_score
from yellowbrick.cluster import SilhouetteVisualizer
from sklearn.metrics import classification_report
from kneed import KneeLocator

# %% [markdown]
# ### LOAD DATA

# %%
# Top Songs
top = pd.read_csv('top_tracks.csv')

# Spotify Dataset
data = pd.read_csv('final_full_list2.csv')

# %%
top
# Out:
#                    track_id                     song_title
# 0    59uQI0PADDKeE6UZDTJEe8                     Last Night  \
# 1    1Lo0QY9cvc8sUB2vnIOxDT                       Fast Car
# 2    1s7oOCT8vauUh01PbJD6ps                      Calm Down
# 3    1s7oOCT8vauUh01PbJD6ps  Calm Down (with Selena Gomez)
# 4    0yLdNVWF3Srea0uzk55zFn                        Flowers
# ..                      ...                            ...
# 159  4lIxdJw6W3Fg4vUIYCB0S5                          Style
# 160  5IAESfJjmOYu7cHyX557kz                       Take Two
# 161  3JvKfv6T31zO0ini8iNItO                   Another Love
# 162  4FAKtPVycI4DxoOHC01YqD                     Yandel 150
# 163  3tt9i3Hhzq84dPS8H7iSiJ                     La Bachata
#
#              artist_name  danceability  energy  key  loudness  mode
# 0          Morgan Wallen         0.517   0.675    6    -5.382     1  \
# 1             Luke Combs         0.712   0.603    8    -5.520     1
# 2    Rema & Selena Gomez         0.799   0.802   11    -5.196     1
# 3                   Rema         0.799   0.802   11    -5.196     1
# 4            Miley Cyrus         0.707   0.681    0    -4.325     1
# ..                   ...           ...     ...  ...       ...   ...
# 159         Taylor Swift         0.598   0.786    2    -5.572     1
# 160                  BTS         0.617   0.589    7    -5.978     1
# 161            Tom Odell         0.445   0.537    4    -8.532     0
# 162               Yandel         0.783   0.729    6    -3.549     0
# 163        Manuel Turizo         0.835   0.679    7    -5.329     0
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0         0.0357       0.45900          0.000000    0.1510    0.518  203.853  \
# 1         0.0262       0.18600          0.000000    0.1150    0.670   97.994
# 2         0.0371       0.42900          0.001280    0.1710    0.811  107.008
# 3         0.0371       0.42900          0.001280    0.1710    0.811  107.008
# 4         0.0668       0.06320          0.000005    0.0322    0.646  117.999
# ..           ...           ...               ...       ...      ...      ...
# 159       0.0383       0.00253          0.001600    0.1170    0.456   95.019
# 160       0.0345       0.02680          0.000000    0.3780    0.566   92.991
# 161       0.0400       0.69500          0.000017    0.0944    0.131  122.769
# 162       0.0691       0.04920          0.000272    0.1000    0.580  167.968
# 163       0.0364       0.58300          0.000002    0.2180    0.850  124.980
#
#                          id  duration_ms
# 0    59uQI0PADDKeE6UZDTJEe8       163855
# 1    1Lo0QY9cvc8sUB2vnIOxDT       265493
# 2    1s7oOCT8vauUh01PbJD6ps       239318
# 3    1s7oOCT8vauUh01PbJD6ps       239318
# 4    0yLdNVWF3Srea0uzk55zFn       200455
# ..                      ...          ...
# 159  4lIxdJw6W3Fg4vUIYCB0S5       231000
# 160  5IAESfJjmOYu7cHyX557kz       229953
# 161  3JvKfv6T31zO0ini8iNItO       244360
# 162  4FAKtPVycI4DxoOHC01YqD       216148
# 163  3tt9i3Hhzq84dPS8H7iSiJ       162638
#
# [164 rows x 16 columns]

# %%
data
# Out:
#                       track_id                     track_name     artist_name
# 0       0gNNToCW3qjabgTyBSjt3H      !Que Vida! - Mono Version            Love  \
# 1       0tMgFpOrXZR6irEOLNWwJL                           "40"              U2
# 2       2ZywW3VyVx6rrlrX75n3JB                    "40" - Live              U2
# 3       6DdWA7D1o5TU2kXWyCLcch         "40" - Remastered 2008              U2
# 4       3vMmwsAiLDCfyc1jl76lQE         "40" - Remastered 2008              U2
# ...                        ...                            ...             ...
# 174035  7JSH9jmLF2BfoZmYlQq5I0                       Physical        Dua Lipa
# 174036  4de1X6v99U7tfOXrNUCTbi                          Candy        Doja Cat
# 174037  1GVF9369j7InydwGztCDIZ                Good In Goodbye    Madison Beer
# 174038  6qNB2ChCVPepl5ZjVJJTUW  STUPID (feat. Yung Baby Tate)        Ashnikko
# 174039  1YrgbwVse66pH7ysXLlgO8               Heartbreak Hotel  Abigail Barlow
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness
# 0              0.600   0.540    9   -11.803     1       0.0328       0.52500  \
# 1              0.368   0.480    8   -11.605     1       0.0306       0.22800
# 2              0.272   0.684    8    -9.728     1       0.0505       0.09980
# 3              0.371   0.545    8    -9.315     1       0.0307       0.18500
# 4              0.371   0.545    8    -9.315     1       0.0307       0.18500
# ...              ...     ...  ...       ...   ...          ...           ...
# 174035         0.643   0.813    0    -4.819     1       0.0492       0.01680
# 174036         0.689   0.516    8    -5.857     1       0.0444       0.51300
# 174037         0.658   0.698   11    -5.950     0       0.1770       0.43300
# 174038         0.772   0.637    2    -6.881     1       0.1140       0.00459
# 174039         0.639   0.837    1    -5.445     1       0.0849       0.13900
#
#         instrumentalness  liveness  valence    tempo  duration_ms
# 0               0.003050    0.1000    0.547  125.898       220560
# 1               0.707000    0.1590    0.338  150.166       157840
# 2               0.014500    0.9460    0.279  143.079       226200
# 3               0.582000    0.1830    0.310  150.316       157667
# 4               0.582000    0.1830    0.310  150.316       157667
# ...                  ...       ...      ...      ...          ...
# 174035          0.000344    0.1030    0.747  146.983       193829
# 174036          0.000000    0.1680    0.209  124.876       190907
# 174037          0.000000    0.1740    0.456  139.054       141949
# 174038          0.000000    0.0778    0.540  149.906       167317
# 174039          0.000001    0.3010    0.621  167.161       196325
#
# [174040 rows x 15 columns]

# %% [markdown]
# ### GET NUMERICAL FEATURES FOR SCALING

# %%
top_nums = top.select_dtypes(np.number)
data_nums = data.select_dtypes(np.number)

# %%
top_nums.columns, data_nums.columns # we don't need the duration so we can drop this on both dfs
# Out:
# (Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#         'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#         'duration_ms'],
#        dtype='object'),
#  Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#         'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#         'duration_ms'],
#        dtype='object'))

# %%
top_nums.drop("duration_ms", axis=1, inplace=True)
data_nums.drop("duration_ms", axis=1, inplace=True)

# %%
top_nums.describe()
# Out:
#        danceability      energy         key    loudness        mode
# count    164.000000  164.000000  164.000000  164.000000  164.000000  \
# mean       0.668890    0.641403    5.432927   -6.592238    0.530488
# std        0.145903    0.152566    3.536195    2.666603    0.500598
# min        0.063000    0.061100    0.000000  -26.901000    0.000000
# 25%        0.572250    0.537750    2.000000   -7.839000    0.000000
# 50%        0.674500    0.647000    6.000000   -6.188000    1.000000
# 75%        0.783000    0.738000    9.000000   -5.015250    1.000000
# max        0.954000    0.988000   11.000000   -0.517000    1.000000
#
#        speechiness  acousticness  instrumentalness    liveness     valence
# count   164.000000    164.000000        164.000000  164.000000  164.000000  \
# mean      0.098019      0.259485          0.041628    0.165896    0.517123
# std       0.100280      0.231773          0.170534    0.113956    0.227812
# min       0.024800      0.000174          0.000000    0.032200    0.038000
# 25%       0.036625      0.068225          0.000000    0.099525    0.366500
# 50%       0.053650      0.187500          0.000001    0.115000    0.508000
# 75%       0.100000      0.426750          0.000080    0.191250    0.694500
# max       0.491000      0.977000          0.974000    0.685000    0.963000
#
#             tempo
# count  164.000000
# mean   125.912744
# std     30.704891
# min     56.664000
# 25%    100.042750
# 50%    125.554500
# 75%    143.272250
# max    203.853000

# %%
data_nums.describe()
# Out:
#         danceability         energy            key       loudness
# count  174040.000000  174040.000000  174040.000000  174040.000000  \
# mean        0.539386       0.491853       5.203562     -11.318403
# std         0.175237       0.268204       3.517539       5.658198
# min         0.000000       0.000000       0.000000     -60.000000
# 25%         0.419000       0.265000       2.000000     -14.405250
# 50%         0.549000       0.484000       5.000000     -10.402000
# 75%         0.669000       0.714000       8.000000      -7.083000
# max         0.988000       1.000000      11.000000       3.855000
#
#                 mode    speechiness   acousticness  instrumentalness
# count  174040.000000  174040.000000  174040.000000     174040.000000  \
# mean        0.705522       0.093972       0.488534          0.165375
# std         0.455809       0.148976       0.376981          0.312228
# min         0.000000       0.000000       0.000000          0.000000
# 25%         0.000000       0.035000       0.089300          0.000000
# 50%         1.000000       0.045200       0.482000          0.000217
# 75%         1.000000       0.075800       0.884000          0.096700
# max         1.000000       0.969000       0.996000          1.000000
#
#             liveness        valence          tempo
# count  174040.000000  174040.000000  174040.000000
# mean        0.206902       0.530258     117.058587
# std         0.176816       0.262338      30.653184
# min         0.000000       0.000000       0.000000
# 25%         0.098400       0.320000      93.662000
# 50%         0.135000       0.542000     115.010000
# 75%         0.263000       0.747000     135.740500
# max         1.000000       1.000000     244.091000

# %% [markdown]
# #### SCALE DATA

# %%
def scaler(df):
    df_scaled = StandardScaler().fit_transform(df)
    df_scaled = pd.DataFrame(df_scaled, columns=df.columns)
    return df_scaled

# %%
top_scaled = scaler(top_nums)
top_scaled.head()
# Out:
# min   -3.078053e+00 -1.833883e+00 -1.479323e+00 -8.603752e+00 -1.547849e+00
# 25%   -6.869924e-01 -8.458254e-01 -9.107424e-01 -5.455545e-01 -1.547849e+00
# 50%    5.486397e-02 -2.928000e-02 -5.787086e-02  1.619607e-01  6.460579e-01
# 75%    7.396545e-01  8.282791e-01  7.950007e-01  7.485449e-01  6.460579e-01
# max    2.560056e+00  1.894635e+00  1.647872e+00  2.681675e+00  6.460579e-01
#
#         speechiness  acousticness  instrumentalness      liveness
# count  1.740400e+05  1.740400e+05      1.740400e+05  1.740400e+05  \
# mean  -9.145115e-18 -3.396757e-16      1.058220e-16 -1.427291e-16
# std    1.000003e+00  1.000003e+00      1.000003e+00  1.000003e+00
# min   -6.307914e-01 -1.295915e+00     -5.296622e-01 -1.170158e+00
# 25%   -3.958530e-01 -1.059033e+00     -5.296622e-01 -6.136463e-01
# 50%   -3.273853e-01 -1.733370e-02     -5.289672e-01 -4.066512e-01
# 75%   -1.219821e-01  1.049035e+00     -2.199513e-01  3.172661e-01
# max    5.873644e+00  1.346133e+00      2.673140e+00  4.485446e+00
#
#             valence         tempo
# count  1.740400e+05  1.740400e+05
# mean  -8.687859e-17 -1.740838e-16
# std    1.000003e+00  1.000003e+00
# min   -2.021283e+00 -3.818818e+00
# 25%   -8.014795e-01 -7.632699e-01
# 50%    4.475916e-02 -6.683132e-02
# 75%    8.261957e-01  6.094625e-01
# max    1.790603e+00  4.144195e+00

# %% [markdown]
# ### K-MEANS CLUSTERING

# %% [markdown]
# #### FINDING THE BEST K

# %% [markdown]
# ##### Functions

# %%
# Function to find the elbow which would determine the best k
def elbow_plot(df_scaled, start, end):
    """Create elbow plot from scaled data"""
    
    sse = {}
    
    for k in range(start, end):
        kmeans = KMeans(n_clusters=k, random_state=1)
        kmeans.fit(df_scaled)
        sse[k] = kmeans.inertia_
    
    fig = plt.figure(figsize = (18,10))
    
    plt.title('Elbow plot for K selection')
    plt.xlabel('k')
    plt.ylabel('SSE')
    plot =  sns.pointplot(x=list(sse.keys()),
                 y=list(sse.values()))    
    
    plt.tight_layout()
    plt.show()

# %%
# another plot using kneed library with the elbow point specified
def find_k(df_scaled, start, end):
    """Find the optimum k clusters"""
    
    sse = {}
    
    for k in range(start, end):
        kmeans = KMeans(n_clusters=k, random_state=1)
        kmeans.fit(df_scaled)
        sse[k] = kmeans.inertia_
    
    kn = KneeLocator(x=list(sse.keys()), 
                 y=list(sse.values()), 
                 curve='convex', 
                 direction='decreasing')
    kn.plot_knee(figsize = ([18,10]), xlabel = "k", ylabel = "SSE")
    k = kn.knee
    return k

# %% [markdown]
# ##### Top Dataset

# %%
elbow_plot(top_scaled, 2, 21)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
top_k = find_k(top_scaled, 2, 21)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
top_k
# Out:
# 9

# %% [markdown]
# **Result for best k: 9.**

# %% [markdown]
# ##### Full Data Dataset

# %%
data_k = find_k(data_scaled, 2, 21)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data_k
# Out:
# 8

# %% [markdown]
# **Result for best k: 8.**

# %% [markdown]
# #### MODEL

# %% [markdown]
# ##### Top

# %%
kmeans = KMeans(n_clusters=top_k, random_state=1)
kmeans.fit(top_scaled)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=9, random_state=1)

# %%
# "performance metric" --> difficult to understand because it is not normalized
kmeans.inertia_
# Out:
# 887.9495641172002

# %%
# Assigning the clusters:
clusters = kmeans.predict(top_scaled)
clusters
# Out:
# array([4, 1, 2, 2, 1, 7, 1, 7, 1, 3, 3, 8, 3, 1, 4, 8, 0, 3, 3, 4, 4, 7,
#        7, 6, 4, 2, 1, 2, 2, 3, 4, 1, 1, 3, 5, 5, 1, 6, 4, 6, 1, 4, 2, 1,
#        7, 7, 1, 3, 4, 2, 2, 4, 4, 4, 2, 1, 3, 1, 3, 3, 6, 1, 4, 4, 8, 7,
#        3, 4, 3, 3, 3, 6, 1, 2, 1, 6, 3, 2, 1, 1, 7, 7, 2, 7, 2, 2, 6, 3,
#        7, 4, 5, 6, 4, 7, 7, 6, 1, 4, 4, 1, 4, 6, 6, 3, 6, 2, 1, 1, 3, 4,
#        2, 1, 7, 1, 0, 6, 1, 7, 8, 5, 2, 4, 4, 6, 3, 5, 2, 1, 6, 2, 1, 2,
#        3, 2, 6, 1, 6, 6, 7, 6, 2, 1, 2, 1, 1, 1, 3, 1, 6, 6, 3, 1, 3, 7,
#        2, 1, 2, 7, 6, 1, 6, 8, 2, 2], dtype=int32)

# %%
def add_cluster_column(df_scaled, k):
    """Run KMeans clustering, and add cluster result to the dataframe. """
    
    kmeans = KMeans(n_clusters=k, 
                    random_state=1)
    kmeans.fit(df_scaled)
    return df_scaled.assign(cluster=kmeans.labels_)

# %%
df_top = add_cluster_column(top_scaled, top_k)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df_top.cluster.unique()
# Out:
# array([4, 1, 2, 7, 3, 8, 0, 6, 5], dtype=int32)

# %%
df_data = add_cluster_column(data_scaled, data_k)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df_data.cluster.unique()
# Out:
# array([0, 5, 6, 7, 1, 2, 4, 3], dtype=int32)

# %% [markdown]
# ### VISUALIZING THE CLUSTERS

# %% [markdown]
# #### TOP

# %%
pca = PCA(2) 
top_2D = pca.fit_transform(top_scaled)
top_2D
# Out:
# array([[-1.56627872e-01, -9.57085814e-01],
#        [-4.67317472e-01, -2.34803877e-01],
#        [-1.31181726e+00, -9.72185716e-01],
#        [-1.31181726e+00, -9.72185716e-01],
#        [-8.41847043e-01,  1.09799232e+00],
#        [ 1.90799618e-01,  2.98599193e+00],
#        [ 1.52458615e+00,  1.61252820e+00],
#        [-3.57466215e-01,  8.43850376e-01],
#        [-3.04688360e-01, -8.52645846e-01],
#        [ 8.39807310e-01,  4.79342229e-01],
#        [ 8.39807310e-01,  4.79342229e-01],
#        [ 5.17591175e+00, -1.46326647e+00],
#        [ 1.01470227e+00,  5.94371629e-02],
#        [-7.37672738e-01, -6.22433585e-01],
#        [-7.25788403e-01, -1.17340062e+00],
#        [-8.41847043e-01,  1.09799232e+00],
#        [-7.66462946e-01, -1.44775552e+00],
#        [-1.05832437e+00, -1.05301081e+00],
#        [-2.31129328e-01,  2.74111481e+00],
#        [-1.54346257e+00, -7.08506790e-01],
#        [-2.21070186e+00, -2.17424771e-01],
#        [-1.28841346e+00,  4.49659169e-01],
#        [-1.22453574e-01, -5.89827807e-01],
#        [-9.92367840e-03,  9.28605319e-01],
#        [-1.17692452e+00,  1.05309555e+00],
#        [ 1.96840885e+00,  3.71736474e-01],
#        [ 1.58695594e-01, -5.53510640e-01],
#        [-7.16252871e-01,  4.74952308e-03],
#        [-1.91281828e+00, -2.02965288e+00],
#        [-9.86112658e-01, -9.62630753e-01],
#        [ 4.88153896e-01,  4.53750623e-01],
#        [-7.71801952e-01,  3.83887706e-01],
#        [ 8.98997747e-01,  8.79130652e-02],
#        [ 3.64312533e-01,  1.97446304e+00],
#        [ 5.99755830e-01,  2.30919378e-01],
#        [-1.18111754e+00,  7.41525040e-01],
#        [-2.27814997e+00, -1.04111060e+00],
#        [-3.49870700e-01,  1.23395406e+00],
#        [-1.40835761e+00,  1.41525008e+00],
#        [-6.44770749e-01,  2.28082502e-02],
#        [-5.29756909e-01, -7.66751558e-01],
#        [ 2.36913455e+00, -7.45012488e-01],
#        [-1.69414904e+00, -1.64739248e-02],
#        [-7.42613254e-01, -5.29525402e-01]])

# %%
kmeans = KMeans(n_clusters=top_k, random_state=1)
kmeans.fit(top_2D)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=9, random_state=1)

# %%
clusters = kmeans.predict(top_2D)
clusters
# Out:
# array([1, 1, 4, 4, 8, 6, 2, 8, 1, 5, 5, 0, 1, 1, 5, 0, 3, 8, 8, 4, 1, 6,
#        6, 4, 7, 1, 5, 1, 1, 1, 4, 2, 5, 1, 7, 7, 2, 4, 1, 4, 4, 5, 1, 4,
#        6, 6, 1, 8, 7, 8, 8, 5, 1, 1, 4, 8, 1, 5, 5, 8, 8, 8, 5, 5, 0, 8,
#        7, 1, 5, 5, 1, 1, 1, 4, 2, 1, 7, 4, 5, 5, 8, 8, 1, 6, 1, 1, 4, 5,
#        6, 4, 7, 8, 2, 8, 2, 4, 5, 1, 1, 5, 5, 4, 4, 1, 4, 7, 5, 8, 1, 4,
#        1, 2, 6, 8, 3, 1, 5, 2, 7, 0, 4, 4, 5, 1, 5, 0, 1, 2, 4, 4, 2, 4,
#        5, 1, 1, 8, 1, 4, 6, 4, 4, 8, 1, 8, 8, 5, 1, 1, 4, 4, 5, 8, 5, 2,
#        5, 8, 4, 8, 8, 1, 1, 0, 4, 1], dtype=int32)

# %%
labels = np.unique(clusters)

for i in labels:
    plt.scatter(top_2D[clusters == i , 0] , top_2D[clusters == i , 1] , label = i)
plt.legend()
plt.show()

# %% [markdown]
# #### DATA

# %%
data_2D = pca.fit_transform(data_scaled)
data_2D
# Out:
# array([[-0.31938605,  0.08663855],
#        [ 0.62073566, -1.61131978],
#        [-0.67496301, -2.43814953],
#        ...,
#        [-1.41447181,  0.30699531],
#        [-1.92864788,  0.07770241],
#        [-2.27481004, -0.80041912]])

# %%
kmeans = KMeans(n_clusters=10, random_state=1)
kmeans.fit(data_2D)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=10, random_state=1)

# %%
clusters_data = kmeans.predict(data_2D)
clusters_data
# Out:
# array([0, 7, 4, ..., 6, 1, 1], dtype=int32)

# %%
# 8 clusters
labels = np.unique(clusters_data)

for i in labels:
    plt.scatter(data_2D[clusters_data == i , 0] , data_2D[clusters_data == i , 1] , label = i)
plt.legend()
plt.show()

# %%
# 9 clusters
labels = np.unique(clusters_data)

for i in labels:
    plt.scatter(data_2D[clusters_data == i , 0] , data_2D[clusters_data == i , 1] , label = i)
plt.legend()
plt.show()

# %%
#10 clusters
labels = np.unique(clusters_data)

for i in labels:
    plt.scatter(data_2D[clusters_data == i , 0] , data_2D[clusters_data == i , 1] , label = i)
plt.legend()
plt.show()

# %% [markdown]
# #### USING SILHOUETTE SCORE TO LOOK FOR BEST K

# %%
def plot_silhouette(df, start, end):
    K = range(start, end)

    silhouette = []

    for k in K:
        kmeans = KMeans(n_clusters=k, random_state=1)
        kmeans.fit(df)
        silhouette.append(silhouette_score(df, kmeans.predict(df)))    

    # plot
    plt.figure(figsize=(16,8))
    plt.plot(K, silhouette, 'bx-')
    plt.xlabel('k')
    plt.ylabel('silhouette score')
    plt.xticks(np.arange(min(K), max(K)+1, 1.0))
    plt.show()

# %%
plot_silhouette(top_scaled, 2, 11)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plot_silhouette(data_scaled, 2, 11)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# **Looking at k from 2 to 10:**
# - We arrive at the same result for the best k for the top dataset : 9.
# - However, we can see the silhouette score for the best k of the full data dataset doesn't align with the highest.
#   - To take a better look at the cluster visualization, we will try out different clusters.
#   - Above, we can see that more clusters will lead to better partioning of the dataset. If we have more time to work on this, it would be ideal to look at larger iterations for looking for the best k just to see if having more clusters or "genre" would be better in determining more accurately which songs are similar. This in turn will provide better recommendation to users.

# %% [markdown]
# ### TRYING OUT SILHOUETTE VISUALIZER

# %%
fig, ax = plt.subplots(3, 2, figsize=(15,15))
for i in [5,6,7,8,9,10]:
    '''
    Create KMeans instance for different number of clusters
    '''
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=1)
    q, mod = divmod(i, 2)
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-4][mod])
    visualizer.fit(top_2D)

# %% [markdown]
# **Also tried doing the silhouette visualizer.**
# - We can see that only k=8 doesn't have below 0 silhouette.
