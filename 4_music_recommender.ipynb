# %% [markdown]
# # Music Recommender

# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

from sklearn.metrics import silhouette_score, pairwise_distances_argmin_min
from yellowbrick.cluster import SilhouetteVisualizer
from kneed import KneeLocator

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import config

# %% [markdown]
# ### LOAD DATASETS

# %%
# Top Songs
top_all = pd.read_csv('top_tracks.csv')

# Spotify Dataset
full_all = pd.read_csv('final_full_list2.csv')

# %%
top_all
# Out:
#                    track_id                     song_title
# 0    59uQI0PADDKeE6UZDTJEe8                     Last Night  \
# 1    1Lo0QY9cvc8sUB2vnIOxDT                       Fast Car
# 2    1s7oOCT8vauUh01PbJD6ps                      Calm Down
# 3    1s7oOCT8vauUh01PbJD6ps  Calm Down (with Selena Gomez)
# 4    0yLdNVWF3Srea0uzk55zFn                        Flowers
# ..                      ...                            ...
# 159  4lIxdJw6W3Fg4vUIYCB0S5                          Style
# 160  5IAESfJjmOYu7cHyX557kz                       Take Two
# 161  3JvKfv6T31zO0ini8iNItO                   Another Love
# 162  4FAKtPVycI4DxoOHC01YqD                     Yandel 150
# 163  3tt9i3Hhzq84dPS8H7iSiJ                     La Bachata
#
#              artist_name  danceability  energy  key  loudness  mode
# 0          Morgan Wallen         0.517   0.675    6    -5.382     1  \
# 1             Luke Combs         0.712   0.603    8    -5.520     1
# 2    Rema & Selena Gomez         0.799   0.802   11    -5.196     1
# 3                   Rema         0.799   0.802   11    -5.196     1
# 4            Miley Cyrus         0.707   0.681    0    -4.325     1
# ..                   ...           ...     ...  ...       ...   ...
# 159         Taylor Swift         0.598   0.786    2    -5.572     1
# 160                  BTS         0.617   0.589    7    -5.978     1
# 161            Tom Odell         0.445   0.537    4    -8.532     0
# 162               Yandel         0.783   0.729    6    -3.549     0
# 163        Manuel Turizo         0.835   0.679    7    -5.329     0
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0         0.0357       0.45900          0.000000    0.1510    0.518  203.853  \
# 1         0.0262       0.18600          0.000000    0.1150    0.670   97.994
# 2         0.0371       0.42900          0.001280    0.1710    0.811  107.008
# 3         0.0371       0.42900          0.001280    0.1710    0.811  107.008
# 4         0.0668       0.06320          0.000005    0.0322    0.646  117.999
# ..           ...           ...               ...       ...      ...      ...
# 159       0.0383       0.00253          0.001600    0.1170    0.456   95.019
# 160       0.0345       0.02680          0.000000    0.3780    0.566   92.991
# 161       0.0400       0.69500          0.000017    0.0944    0.131  122.769
# 162       0.0691       0.04920          0.000272    0.1000    0.580  167.968
# 163       0.0364       0.58300          0.000002    0.2180    0.850  124.980
#
#                          id  duration_ms
# 0    59uQI0PADDKeE6UZDTJEe8       163855
# 1    1Lo0QY9cvc8sUB2vnIOxDT       265493
# 2    1s7oOCT8vauUh01PbJD6ps       239318
# 3    1s7oOCT8vauUh01PbJD6ps       239318
# 4    0yLdNVWF3Srea0uzk55zFn       200455
# ..                      ...          ...
# 159  4lIxdJw6W3Fg4vUIYCB0S5       231000
# 160  5IAESfJjmOYu7cHyX557kz       229953
# 161  3JvKfv6T31zO0ini8iNItO       244360
# 162  4FAKtPVycI4DxoOHC01YqD       216148
# 163  3tt9i3Hhzq84dPS8H7iSiJ       162638
#
# [164 rows x 16 columns]

# %%
top_all.drop(["id", "duration_ms"], axis=1, inplace=True)

# %%
full_all.drop("duration_ms", axis=1, inplace=True)

# %%
full_all.columns = ['track_id', 'song_title', 'artist_name', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo']

# %%
# add labels for filtering
top_all['group']= "t"
# add labels for filtering
full_all['group']= "f"

# %%
top_all
# Out:
#                    track_id                     song_title
# 0    59uQI0PADDKeE6UZDTJEe8                     Last Night  \
# 1    1Lo0QY9cvc8sUB2vnIOxDT                       Fast Car
# 2    1s7oOCT8vauUh01PbJD6ps                      Calm Down
# 3    1s7oOCT8vauUh01PbJD6ps  Calm Down (with Selena Gomez)
# 4    0yLdNVWF3Srea0uzk55zFn                        Flowers
# ..                      ...                            ...
# 159  4lIxdJw6W3Fg4vUIYCB0S5                          Style
# 160  5IAESfJjmOYu7cHyX557kz                       Take Two
# 161  3JvKfv6T31zO0ini8iNItO                   Another Love
# 162  4FAKtPVycI4DxoOHC01YqD                     Yandel 150
# 163  3tt9i3Hhzq84dPS8H7iSiJ                     La Bachata
#
#              artist_name  danceability  energy  key  loudness  mode
# 0          Morgan Wallen         0.517   0.675    6    -5.382     1  \
# 1             Luke Combs         0.712   0.603    8    -5.520     1
# 2    Rema & Selena Gomez         0.799   0.802   11    -5.196     1
# 3                   Rema         0.799   0.802   11    -5.196     1
# 4            Miley Cyrus         0.707   0.681    0    -4.325     1
# ..                   ...           ...     ...  ...       ...   ...
# 159         Taylor Swift         0.598   0.786    2    -5.572     1
# 160                  BTS         0.617   0.589    7    -5.978     1
# 161            Tom Odell         0.445   0.537    4    -8.532     0
# 162               Yandel         0.783   0.729    6    -3.549     0
# 163        Manuel Turizo         0.835   0.679    7    -5.329     0
#
#      speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0         0.0357       0.45900          0.000000    0.1510    0.518  203.853  \
# 1         0.0262       0.18600          0.000000    0.1150    0.670   97.994
# 2         0.0371       0.42900          0.001280    0.1710    0.811  107.008
# 3         0.0371       0.42900          0.001280    0.1710    0.811  107.008
# 4         0.0668       0.06320          0.000005    0.0322    0.646  117.999
# ..           ...           ...               ...       ...      ...      ...
# 159       0.0383       0.00253          0.001600    0.1170    0.456   95.019
# 160       0.0345       0.02680          0.000000    0.3780    0.566   92.991
# 161       0.0400       0.69500          0.000017    0.0944    0.131  122.769
# 162       0.0691       0.04920          0.000272    0.1000    0.580  167.968
# 163       0.0364       0.58300          0.000002    0.2180    0.850  124.980
#
#     group
# 0       t
# 1       t
# 2       t
# 3       t
# 4       t
# ..    ...
# 159     t
# 160     t
# 161     t
# 162     t
# 163     t
#
# [164 rows x 15 columns]

# %%
full_all
# Out:
#                       track_id                     song_title     artist_name
# 0       0gNNToCW3qjabgTyBSjt3H      !Que Vida! - Mono Version            Love  \
# 1       0tMgFpOrXZR6irEOLNWwJL                           "40"              U2
# 2       2ZywW3VyVx6rrlrX75n3JB                    "40" - Live              U2
# 3       6DdWA7D1o5TU2kXWyCLcch         "40" - Remastered 2008              U2
# 4       3vMmwsAiLDCfyc1jl76lQE         "40" - Remastered 2008              U2
# ...                        ...                            ...             ...
# 174035  7JSH9jmLF2BfoZmYlQq5I0                       Physical        Dua Lipa
# 174036  4de1X6v99U7tfOXrNUCTbi                          Candy        Doja Cat
# 174037  1GVF9369j7InydwGztCDIZ                Good In Goodbye    Madison Beer
# 174038  6qNB2ChCVPepl5ZjVJJTUW  STUPID (feat. Yung Baby Tate)        Ashnikko
# 174039  1YrgbwVse66pH7ysXLlgO8               Heartbreak Hotel  Abigail Barlow
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness
# 0              0.600   0.540    9   -11.803     1       0.0328       0.52500  \
# 1              0.368   0.480    8   -11.605     1       0.0306       0.22800
# 2              0.272   0.684    8    -9.728     1       0.0505       0.09980
# 3              0.371   0.545    8    -9.315     1       0.0307       0.18500
# 4              0.371   0.545    8    -9.315     1       0.0307       0.18500
# ...              ...     ...  ...       ...   ...          ...           ...
# 174035         0.643   0.813    0    -4.819     1       0.0492       0.01680
# 174036         0.689   0.516    8    -5.857     1       0.0444       0.51300
# 174037         0.658   0.698   11    -5.950     0       0.1770       0.43300
# 174038         0.772   0.637    2    -6.881     1       0.1140       0.00459
# 174039         0.639   0.837    1    -5.445     1       0.0849       0.13900
#
#         instrumentalness  liveness  valence    tempo group
# 0               0.003050    0.1000    0.547  125.898     f
# 1               0.707000    0.1590    0.338  150.166     f
# 2               0.014500    0.9460    0.279  143.079     f
# 3               0.582000    0.1830    0.310  150.316     f
# 4               0.582000    0.1830    0.310  150.316     f
# ...                  ...       ...      ...      ...   ...
# 174035          0.000344    0.1030    0.747  146.983     f
# 174036          0.000000    0.1680    0.209  124.876     f
# 174037          0.000000    0.1740    0.456  139.054     f
# 174038          0.000000    0.0778    0.540  149.906     f
# 174039          0.000001    0.3010    0.621  167.161     f
#
# [174040 rows x 15 columns]

# %%
# Joining 2 dfs together including group labels t for top list and f for full list
all = pd.concat([top_all, full_all])

# %%
all
# Out:
#                       track_id                     song_title
# 0       59uQI0PADDKeE6UZDTJEe8                     Last Night  \
# 1       1Lo0QY9cvc8sUB2vnIOxDT                       Fast Car
# 2       1s7oOCT8vauUh01PbJD6ps                      Calm Down
# 3       1s7oOCT8vauUh01PbJD6ps  Calm Down (with Selena Gomez)
# 4       0yLdNVWF3Srea0uzk55zFn                        Flowers
# ...                        ...                            ...
# 174035  7JSH9jmLF2BfoZmYlQq5I0                       Physical
# 174036  4de1X6v99U7tfOXrNUCTbi                          Candy
# 174037  1GVF9369j7InydwGztCDIZ                Good In Goodbye
# 174038  6qNB2ChCVPepl5ZjVJJTUW  STUPID (feat. Yung Baby Tate)
# 174039  1YrgbwVse66pH7ysXLlgO8               Heartbreak Hotel
#
#                 artist_name  danceability  energy  key  loudness  mode
# 0             Morgan Wallen         0.517   0.675    6    -5.382     1  \
# 1                Luke Combs         0.712   0.603    8    -5.520     1
# 2       Rema & Selena Gomez         0.799   0.802   11    -5.196     1
# 3                      Rema         0.799   0.802   11    -5.196     1
# 4               Miley Cyrus         0.707   0.681    0    -4.325     1
# ...                     ...           ...     ...  ...       ...   ...
# 174035             Dua Lipa         0.643   0.813    0    -4.819     1
# 174036             Doja Cat         0.689   0.516    8    -5.857     1
# 174037         Madison Beer         0.658   0.698   11    -5.950     0
# 174038             Ashnikko         0.772   0.637    2    -6.881     1
# 174039       Abigail Barlow         0.639   0.837    1    -5.445     1
#
#         speechiness  acousticness  instrumentalness  liveness  valence
# 0            0.0357       0.45900          0.000000    0.1510    0.518  \
# 1            0.0262       0.18600          0.000000    0.1150    0.670
# 2            0.0371       0.42900          0.001280    0.1710    0.811
# 3            0.0371       0.42900          0.001280    0.1710    0.811
# 4            0.0668       0.06320          0.000005    0.0322    0.646
# ...             ...           ...               ...       ...      ...
# 174035       0.0492       0.01680          0.000344    0.1030    0.747
# 174036       0.0444       0.51300          0.000000    0.1680    0.209
# 174037       0.1770       0.43300          0.000000    0.1740    0.456
# 174038       0.1140       0.00459          0.000000    0.0778    0.540
# 174039       0.0849       0.13900          0.000001    0.3010    0.621
#
#           tempo group
# 0       203.853     t
# 1        97.994     t
# 2       107.008     t
# 3       107.008     t
# 4       117.999     t
# ...         ...   ...
# 174035  146.983     f
# 174036  124.876     f
# 174037  139.054     f
# 174038  149.906     f
# 174039  167.161     f
#
# [174204 rows x 15 columns]

# %%
# remove track ids to find more duplicates
all_no_id = all.drop("track_id", axis=1)

# %%
# found same song at the top of the list. Duplicate can be removed right away.
all_no_id = all_no_id.drop(index=3).reset_index(drop=True)

# %%
all_no_id
# Out:
#                            song_title                 artist_name
# 0                          Last Night               Morgan Wallen  \
# 1                            Fast Car                  Luke Combs
# 2                           Calm Down         Rema & Selena Gomez
# 3                             Flowers                 Miley Cyrus
# 4                         All My Life  Lil Durk Featuring J. Cole
# ...                               ...                         ...
# 174197                       Physical                    Dua Lipa
# 174198                          Candy                    Doja Cat
# 174199                Good In Goodbye                Madison Beer
# 174200  STUPID (feat. Yung Baby Tate)                    Ashnikko
# 174201               Heartbreak Hotel              Abigail Barlow
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness
# 0              0.517   0.675    6    -5.382     1       0.0357       0.45900  \
# 1              0.712   0.603    8    -5.520     1       0.0262       0.18600
# 2              0.799   0.802   11    -5.196     1       0.0371       0.42900
# 3              0.707   0.681    0    -4.325     1       0.0668       0.06320
# 4              0.829   0.436    3    -8.205     1       0.3270       0.15000
# ...              ...     ...  ...       ...   ...          ...           ...
# 174197         0.643   0.813    0    -4.819     1       0.0492       0.01680
# 174198         0.689   0.516    8    -5.857     1       0.0444       0.51300
# 174199         0.658   0.698   11    -5.950     0       0.1770       0.43300
# 174200         0.772   0.637    2    -6.881     1       0.1140       0.00459
# 174201         0.639   0.837    1    -5.445     1       0.0849       0.13900
#
#         instrumentalness  liveness  valence    tempo group
# 0               0.000000    0.1510    0.518  203.853     t
# 1               0.000000    0.1150    0.670   97.994     t
# 2               0.001280    0.1710    0.811  107.008     t
# 3               0.000005    0.0322    0.646  117.999     t
# 4               0.000000    0.0954    0.693  143.031     t
# ...                  ...       ...      ...      ...   ...
# 174197          0.000344    0.1030    0.747  146.983     f
# 174198          0.000000    0.1680    0.209  124.876     f
# 174199          0.000000    0.1740    0.456  139.054     f
# 174200          0.000000    0.0778    0.540  149.906     f
# 174201          0.000001    0.3010    0.621  167.161     f
#
# [174202 rows x 14 columns]

# %%
# checking for duplicates. Found 3914
all_no_id.duplicated().sum()
# Out:
# 3914

# %%
# drop duplicates
song_list = all_no_id.drop_duplicates()

# %%
song_list
# Out:
#                            song_title                 artist_name
# 0                          Last Night               Morgan Wallen  \
# 1                            Fast Car                  Luke Combs
# 2                           Calm Down         Rema & Selena Gomez
# 3                             Flowers                 Miley Cyrus
# 4                         All My Life  Lil Durk Featuring J. Cole
# ...                               ...                         ...
# 174197                       Physical                    Dua Lipa
# 174198                          Candy                    Doja Cat
# 174199                Good In Goodbye                Madison Beer
# 174200  STUPID (feat. Yung Baby Tate)                    Ashnikko
# 174201               Heartbreak Hotel              Abigail Barlow
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness
# 0              0.517   0.675    6    -5.382     1       0.0357       0.45900  \
# 1              0.712   0.603    8    -5.520     1       0.0262       0.18600
# 2              0.799   0.802   11    -5.196     1       0.0371       0.42900
# 3              0.707   0.681    0    -4.325     1       0.0668       0.06320
# 4              0.829   0.436    3    -8.205     1       0.3270       0.15000
# ...              ...     ...  ...       ...   ...          ...           ...
# 174197         0.643   0.813    0    -4.819     1       0.0492       0.01680
# 174198         0.689   0.516    8    -5.857     1       0.0444       0.51300
# 174199         0.658   0.698   11    -5.950     0       0.1770       0.43300
# 174200         0.772   0.637    2    -6.881     1       0.1140       0.00459
# 174201         0.639   0.837    1    -5.445     1       0.0849       0.13900
#
#         instrumentalness  liveness  valence    tempo group
# 0               0.000000    0.1510    0.518  203.853     t
# 1               0.000000    0.1150    0.670   97.994     t
# 2               0.001280    0.1710    0.811  107.008     t
# 3               0.000005    0.0322    0.646  117.999     t
# 4               0.000000    0.0954    0.693  143.031     t
# ...                  ...       ...      ...      ...   ...
# 174197          0.000344    0.1030    0.747  146.983     f
# 174198          0.000000    0.1680    0.209  124.876     f
# 174199          0.000000    0.1740    0.456  139.054     f
# 174200          0.000000    0.0778    0.540  149.906     f
# 174201          0.000001    0.3010    0.621  167.161     f
#
# [170288 rows x 14 columns]

# %% [markdown]
# ### TRANSFORMATION

# %%
# get audio features
song_list_features = song_list.select_dtypes(np.number)

# %%
song_list_features
# Out:
#         danceability  energy  key  loudness  mode  speechiness  acousticness
# 0              0.517   0.675    6    -5.382     1       0.0357       0.45900  \
# 1              0.712   0.603    8    -5.520     1       0.0262       0.18600
# 2              0.799   0.802   11    -5.196     1       0.0371       0.42900
# 3              0.707   0.681    0    -4.325     1       0.0668       0.06320
# 4              0.829   0.436    3    -8.205     1       0.3270       0.15000
# ...              ...     ...  ...       ...   ...          ...           ...
# 174197         0.643   0.813    0    -4.819     1       0.0492       0.01680
# 174198         0.689   0.516    8    -5.857     1       0.0444       0.51300
# 174199         0.658   0.698   11    -5.950     0       0.1770       0.43300
# 174200         0.772   0.637    2    -6.881     1       0.1140       0.00459
# 174201         0.639   0.837    1    -5.445     1       0.0849       0.13900
#
#         instrumentalness  liveness  valence    tempo
# 0               0.000000    0.1510    0.518  203.853
# 1               0.000000    0.1150    0.670   97.994
# 2               0.001280    0.1710    0.811  107.008
# 3               0.000005    0.0322    0.646  117.999
# 4               0.000000    0.0954    0.693  143.031
# ...                  ...       ...      ...      ...
# 174197          0.000344    0.1030    0.747  146.983
# 174198          0.000000    0.1680    0.209  124.876
# 174199          0.000000    0.1740    0.456  139.054
# 174200          0.000000    0.0778    0.540  149.906
# 174201          0.000001    0.3010    0.621  167.161
#
# [170288 rows x 11 columns]

# %%
# scaling features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(song_list_features)
scaled_features = pd.DataFrame(scaled_features, columns=song_list_features.columns)
scaled_features.head()
# Out:
#    danceability    energy       key  loudness      mode  speechiness
# 0     -0.131078  0.685544  0.227286  1.053706  0.645564    -0.392084  \
# 1      0.981581  0.416409  0.795840  1.029208  0.645564    -0.455326
# 2      1.477998  1.160269  1.648672  1.086726  0.645564    -0.382764
# 3      0.953051  0.707972 -1.478378  1.241351  0.645564    -0.185049
# 4      1.649176 -0.207836 -0.625546  0.552552  0.645564     1.547124
#
#    acousticness  instrumentalness  liveness   valence     tempo
# 0     -0.078722         -0.527896 -0.316878 -0.050361  2.830315
# 1     -0.804190         -0.527896 -0.520225  0.529286 -0.622168
# 2     -0.158444         -0.523783 -0.203907  1.066984 -0.328186
# 3     -1.130518         -0.527879 -0.987923  0.437762  0.030274
# 4     -0.899856         -0.527896 -0.630936  0.616995  0.846668

# %%
scaled_features.shape
# Out:
# (170288, 11)

# %%
pca = PCA(2) 
list_2D = pca.fit_transform(scaled_features)

# %% [markdown]
# > - From previous modeling, tuning and evaluation, we found the best k to be 7.
# > - Also, applying PCA and KMeans model resulted in the best silhouette score.

# %% [markdown]
# ### K-MEANS

# %%
model = KMeans(n_clusters=7, random_state=1, n_init=10)
clusters =  model.fit_predict(list_2D)

# %%
len(clusters)
# Out:
# 170288

# %%
song_list.insert(14, "cluster", clusters)

# %%
song_list
# Out:
#                            song_title                 artist_name
# 0                          Last Night               Morgan Wallen  \
# 1                            Fast Car                  Luke Combs
# 2                           Calm Down         Rema & Selena Gomez
# 3                             Flowers                 Miley Cyrus
# 4                         All My Life  Lil Durk Featuring J. Cole
# ...                               ...                         ...
# 174197                       Physical                    Dua Lipa
# 174198                          Candy                    Doja Cat
# 174199                Good In Goodbye                Madison Beer
# 174200  STUPID (feat. Yung Baby Tate)                    Ashnikko
# 174201               Heartbreak Hotel              Abigail Barlow
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness
# 0              0.517   0.675    6    -5.382     1       0.0357       0.45900  \
# 1              0.712   0.603    8    -5.520     1       0.0262       0.18600
# 2              0.799   0.802   11    -5.196     1       0.0371       0.42900
# 3              0.707   0.681    0    -4.325     1       0.0668       0.06320
# 4              0.829   0.436    3    -8.205     1       0.3270       0.15000
# ...              ...     ...  ...       ...   ...          ...           ...
# 174197         0.643   0.813    0    -4.819     1       0.0492       0.01680
# 174198         0.689   0.516    8    -5.857     1       0.0444       0.51300
# 174199         0.658   0.698   11    -5.950     0       0.1770       0.43300
# 174200         0.772   0.637    2    -6.881     1       0.1140       0.00459
# 174201         0.639   0.837    1    -5.445     1       0.0849       0.13900
#
#         instrumentalness  liveness  valence    tempo group  cluster
# 0               0.000000    0.1510    0.518  203.853     t        0
# 1               0.000000    0.1150    0.670   97.994     t        2
# 2               0.001280    0.1710    0.811  107.008     t        2
# 3               0.000005    0.0322    0.646  117.999     t        2
# 4               0.000000    0.0954    0.693  143.031     t        2
# ...                  ...       ...      ...      ...   ...      ...
# 174197          0.000344    0.1030    0.747  146.983     f        2
# 174198          0.000000    0.1680    0.209  124.876     f        6
# 174199          0.000000    0.1740    0.456  139.054     f        2
# 174200          0.000000    0.0778    0.540  149.906     f        2
# 174201          0.000001    0.3010    0.621  167.161     f        0
#
# [170288 rows x 15 columns]

# %% [markdown]
# **Now that the data is prepared, time to create the music recommender!**

# %%
# connecting to spotipy api
client_credentials_manager = SpotifyClientCredentials(client_id=config.client_id, client_secret=config.client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager, requests_timeout=120)

# %%
def song_recommendation():
    ''' This function will:
    1. take the song title and artist input from the user 
    2. to search the spotipy api for its track id and audio features
    3. If the song is in the top_list df, take another song from the same df with the closest audio features
    4. If the song is NOT in the top_list, take a song from the full_list df to recommend the one with the closest audio features.'''
    
    # input search
    choice = input("Choose a song title and artist name you like :")
    
    # look for the audio features in the spotipy api
    search = sp.search(q=choice, type='track', limit=1)
    
    # get track id needed to get audio features
    try :
        track_id = search["tracks"]['items'][0]["id"]
        song_title = search['tracks']['items'][0]["name"]
        artist_name = search['tracks']['items'][0]["artists"][0]["name"]
    except (IndexError, TypeError):
        print("Sorry, we cannot locate this song. Please choose another.")
    
    # get audio features using the track id
    features = sp.audio_features(track_id)
    features_df = pd.DataFrame(features)
    audio_features = features_df[song_list_features.columns]
    
    # scale the features
    scaled = scaler.transform(audio_features)
    scaled_2D = pca.transform(scaled)
    
    # model
    cluster = model.predict(scaled_2D)
    
    # filter dataframe with same cluster
    filtered_list = song_list[song_list['cluster']==cluster[0]]
    filtered_top = filtered_list[filtered_list['group']== "t"]
    filtered_other = filtered_list[filtered_list['group']== "f"]
    
    # condition to choose song from top list or full list
    if track_id in list(top_all.track_id):
        closest, _ = pairwise_distances_argmin_min(scaled, filtered_top[song_list_features.columns])
    else:
        closest, _ = pairwise_distances_argmin_min(scaled, filtered_other[song_list_features.columns])
    
    # return recommendation
    print("Here's a song you might like!")
    return ' - '.join([filtered_list.iloc[closest[0]]['song_title'], filtered_list.iloc[closest[0]]['artist_name']])

# %% [markdown]
# ### TRYING IT OUT

# %%
# Take Two - BTS (in the top list)
top_all[top_all.song_title == 'Take Two'] # recommended another song in the top list
# Out:
#                    track_id song_title artist_name  danceability  energy  key
# 160  5IAESfJjmOYu7cHyX557kz   Take Two         BTS         0.617   0.589    7  \
#
#      loudness  mode  speechiness  acousticness  instrumentalness  liveness
# 160    -5.978     1       0.0345        0.0268               0.0     0.378  \
#
#      valence   tempo group
# 160    0.566  92.991     t

# %%
# Take Two - BTS (in the top list)
song_recommendation()
# Out:
# Here's a song you might like!
# /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(
# 'Mourning - Post Malone'

# %%
# Mourning - Post Malone (in the top list)
top_all[top_all.song_title == 'Mourning'] # recommended another song in the top list
# Out:
#                   track_id song_title  artist_name  danceability  energy  key
# 75  0gWrMbx6pbdH3n3nsLjE55   Mourning  Post Malone         0.596   0.651    9  \
#
#     loudness  mode  speechiness  acousticness  instrumentalness  liveness
# 75    -4.604     1       0.0331        0.0971               0.0     0.279  \
#
#     valence   tempo group
# 75    0.255  73.959     t

# %%
# Now try a song that's not in the top list
top_all[top_all.song_title == 'Vampire'] # recommended another song in the top list
# Out:
# Empty DataFrame
# Columns: [track_id, song_title, artist_name, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, group]
# Index: []

# %%
# Vampire - Olivia Rodrigo
song_recommendation()
# Out:
# Here's a song you might like!
# /opt/homebrew/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but PCA was fitted with feature names
#   warnings.warn(
# 'Love Broke Thru - TobyMac'

# %%
# Love Broke Thru - TobyMac (NOT in the top list)
top_all[top_all.song_title == 'Love Broke Thru'] # recommended a song NOT in the top list
# Out:
# Empty DataFrame
# Columns: [track_id, song_title, artist_name, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, group]
# Index: []

# %%
full_all[full_all.song_title == 'Love Broke Thru']
# Out:
#                      track_id       song_title artist_name  danceability
# 83568  1NZWiuy0mlnsrcYL2dhKt6  Love Broke Thru     TobyMac         0.672  \
#
#        energy  key  loudness  mode  speechiness  acousticness
# 83568   0.893    0    -3.984     1       0.0337        0.0101  \
#
#        instrumentalness  liveness  valence   tempo group
# 83568               0.0    0.0934    0.543  102.98     f
